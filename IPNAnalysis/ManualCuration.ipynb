# %%
import mea_analysis_pipeline as msp


waveform_folder = '/pscratch/sd/m/mpatil1/MEA_Analysis_V1/AnalyzedData/CHD8_2/CHD8_2/230915/16364/Network/000190/waveforms_good/'

# %%
msp.analyse_waveforms_sigui(waveform_folder)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 msp.analyse_waveforms_sigui(waveform_folder)
#
# File /pscratch/sd/m/mpatil1/MEA_Analysis_V1/IPNAnalysis/mea_analysis_pipeline.py:256, in analyse_waveforms_sigui(waveforms_folder)
#     255 def analyse_waveforms_sigui(waveforms_folder) :
# --> 256     import spikeinterface_gui
#     257     waveforms = si.load_waveforms(waveforms_folder)
#     258     # This creates a Qt app
#     259    # waveforms.run_extract_waveforms(**job_kwargs)
#
# File ~/.local/lib/python3.8/site-packages/spikeinterface_gui/__init__.py:7
#       1 """
#       2 GUI without copy on top of spikeinterface objects
#       3 """
#       5 from .version import version as __version__
# ----> 7 from .myqt import QT, mkQApp
#       8 from .mainwindow import MainWindow
#       9 from .controller import SpikeinterfaceController
#
# ImportError: cannot import name 'mkQApp' from 'spikeinterface_gui.myqt' (/global/homes/m/mpatil1/.local/lib/python3.8/site-packages/spikeinterface_gui/myqt.py)

# %%
# !pip install PyQt6
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyQt6
#   Using cached PyQt6-6.6.0.tar.gz (1.0 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       Traceback (most recent call last):
#         File "/global/homes/m/mpatil1/.local/lib/python3.8/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/global/homes/m/mpatil1/.local/lib/python3.8/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/global/homes/m/mpatil1/.local/lib/python3.8/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 152, in prepare_metadata_for_build_wheel
#           whl_basename = backend.build_wheel(metadata_directory, config_settings)
#         File "/tmp/pip-build-env-_epfzsgd/overlay/lib/python3.8/site-packages/sipbuild/api.py", line 46, in build_wheel
#           project = AbstractProject.bootstrap('wheel',
#         File "/tmp/pip-build-env-_epfzsgd/overlay/lib/python3.8/site-packages/sipbuild/abstract_project.py", line 87, in bootstrap
#           project.setup(pyproject, tool, tool_description)
#         File "/tmp/pip-build-env-_epfzsgd/overlay/lib/python3.8/site-packages/sipbuild/project.py", line 586, in setup
#           self.apply_user_defaults(tool)
#         File "project.py", line 66, in apply_user_defaults
#           super().apply_user_defaults(tool)
#         File "/tmp/pip-build-env-_epfzsgd/overlay/lib/python3.8/site-packages/pyqtbuild/project.py", line 70, in apply_user_defaults
#           super().apply_user_defaults(tool)
#         File "/tmp/pip-build-env-_epfzsgd/overlay/lib/python3.8/site-packages/sipbuild/project.py", line 237, in apply_user_defaults
#           self.builder.apply_user_defaults(tool)
#         File "/tmp/pip-build-env-_epfzsgd/overlay/lib/python3.8/site-packages/pyqtbuild/builder.py", line 69, in apply_user_defaults
#           raise PyProjectOptionException('qmake',
#       sipbuild.pyproject.PyProjectOptionException
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip freeze
# Out:
# anyio==4.0.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# asciitree==0.3.3
# asn1crypto==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==23.1.0
# Babel==2.13.1
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==6.1.0
# certifi==2019.11.28
# cffi==1.14.0
# chardet==3.0.4
# charset-normalizer==3.3.2
# comm==0.2.0
# conda==4.8.2
# conda-package-handling==1.6.0
# contourpy==1.1.1
# cryptography==2.8
# cuda-python==12.2.0
# currentscape==1.0.8
# cycler==0.12.1
# Cython==3.0.2
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# distinctipy==1.2.2
# entrypoints==0.4
# et-xmlfile==1.1.0
# exceptiongroup==1.1.3
# executing==2.0.1
# fasteners==0.18
# fastjsonschema==2.18.1
# fonttools==4.43.1
# h5py==3.10.0
# idna==2.8
# importlib-metadata==6.8.0
# importlib-resources==6.1.0
# ipykernel==6.26.0
# ipython==8.12.3
# ipywidgets==8.1.1
# jedi==0.19.1
# Jinja2==3.1.2
# joblib==1.3.2
# json5==0.9.14
# jsonschema==4.19.2
# jsonschema-specifications==2023.7.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.9.0
# jupyter-lsp==2.2.0
# jupyter_client==8.6.0
# jupyter_core==5.5.0
# jupyter_server==2.10.0
# jupyter_server_terminals==0.4.4
# jupyterlab==4.0.8
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.9
# jupyterlab_server==2.25.1
# kiwisolver==1.4.5
# llvmlite==0.40.1
# MarkupSafe==2.1.3
# matplotlib==3.7.3
# matplotlib-inline==0.1.6
# mistune==3.0.2
# nbclient==0.9.0
# nbconvert==7.11.0
# nbformat==5.9.2
# neo==0.12.0
# nest-asyncio==1.5.8
# networkx==3.1
# notebook==7.0.6
# notebook_shim==0.2.3
# numba==0.57.1
# numcodecs==0.11.0
# numpy==1.24.4
# openpyxl==3.1.2
# overrides==7.4.0
# packaging==23.2
# palettable==3.3.3
# pandas==2.0.3
# pandocfilters==1.5.0
# parso==0.8.3
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==10.1.0
# pkgutil_resolve_name==1.3.10
# platformdirs==3.11.0
# probeinterface==0.2.19
# prometheus-client==0.18.0
# prompt-toolkit==3.0.39
# psutil==5.9.6
# ptyprocess==0.7.0
# pure-eval==0.2.2
# pycosat==0.6.3
# pycparser==2.19
# Pygments==2.16.1
# pyOpenSSL==19.1.0
# pyparsing==3.1.1
# PyQt5==5.15.10
# PyQt5-Qt5==5.15.2
# PyQt5-sip==12.13.0
# pyqtgraph==0.13.3
# PySocks==1.7.1
# python-dateutil==2.8.2
# python-json-logger==2.0.7
# pytz==2023.3.post1
# PyYAML==6.0.1
# pyzmq==25.1.1
# qtconsole==5.5.0
# QtPy==2.4.1
# quantities==0.14.1
# referencing==0.30.2
# requests==2.31.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.12.0
# ruamel_yaml==0.15.87
# scikit-learn==1.3.0
# scipy==1.10.1
# Send2Trash==1.8.2
# shiboken6==6.2.4
# simdkalman==1.0.2
# six==1.14.0
# sniffio==1.3.0
# soupsieve==2.5
# spikeinterface==0.99.1
# spikeinterface-gui==0.7.0
# stack-data==0.6.3
# terminado==0.17.1
# threadpoolctl==3.2.0
# tinycss2==1.2.1
# tomli==2.0.1
# tornado==6.3.3
# tqdm==4.42.1
# traitlets==5.13.0
# tsmoothie==1.0.4
# typing_extensions==4.8.0
# tzdata==2023.3
# urllib3==1.25.8
# wcwidth==0.2.9
# webencodings==0.5.1
# websocket-client==1.6.4
# widgetsnbextension==4.0.9
# xarray==2023.1.0
# zarr==2.16.1
# zipp==3.17.0

# %%
# !python --version
