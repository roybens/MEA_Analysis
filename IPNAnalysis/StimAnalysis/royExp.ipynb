# %%
import sys
sys.path.append('/mnt/disk15tb/nathaniel/MEA_Analysis/IPNAnalysis/')

from StimAnalysis import StimulationAnalysis
from stim_helper_functions import *

# %%
fp = '/home/nathaniel/Downloads/data.raw.h5'
assay = StimulationAnalysis(fp, stim_frequency=0.01, 
                         recording_electrode=7785, stim_electrode=7784, artifact_electrode=6904,
                         spike_threshold=8, peak_sign="neg")
assay.stim_start = 61
#assay.run_full_analysis()
assay.visible_artifact = True
assay.get_spike_counts()
# Out:
#             Time Range                                        Channel 804  \
# 0          0 to 100000                                                 []
# 1     100000 to 200000                                                 []
# 2     200000 to 300000                                                 []
# 3     300000 to 400000                                                 []
# 4     400000 to 500000                                                 []
# 5     500000 to 600000                                                 []
# 6     600000 to 700000  [7662, 7763, 7865, 7966, 8068, 8169, 8271, 837...
# 7     700000 to 800000  [27, 128, 230, 331, 433, 534, 636, 737, 839, 9...
# 8     800000 to 900000  [4, 106, 207, 309, 410, 512, 613, 714, 816, 91...
# 9    900000 to 1000000  [83, 185, 286, 388, 489, 591, 692, 794, 895, 9...
# 10  1000000 to 1100000                                                 []
# 11  1100000 to 1200000                                                 []
# 12  1200000 to 1300000                                                 []
# 13  1300000 to 1400000                                                 []
# 14  1400000 to 1500000                                                 []
#
#                                           Channel 656 Channel 620
# 0   [13006, 14348, 15536, 16291, 16936, 17805, 184...          []
# 1   [313, 1688, 2511, 3568, 3967, 5639, 6813, 8162...          []
# 2   [1860, 4483, 7351, 8976, 10558, 12722, 14111, ...          []
# 3   [135, 397, 943, 1222, 1592, 1882, 2106, 2373, ...          []
# 4   [38037, 39077, 39627, 40222, 40857, 41274, 415...          []
# 5   [383, 7314, 10107, 11819, 13509, 14636, 15663,...          []
# 6   [7661, 7864, 8067, 8270, 8473, 8676, 8879, 908...          []
# 7   [26, 229, 432, 635, 838, 1041, 1244, 1447, 165...          []
# 8   [2, 105, 308, 511, 714, 917, 1120, 1323, 1526,...          []
# 9   [77, 184, 387, 590, 793, 995, 1199, 1402, 1605...          []
# 10  [1501, 3116, 3973, 4555, 5708, 6674, 18000, 33...          []
# 11  [8023, 9674, 11164, 12281, 13159, 13898, 14325...          []
# 12  [2333, 6403, 8247, 10111, 12163, 13159, 14634,...          []
# 13  [13533, 14859, 15444, 16108, 16538, 17449, 178...          []
# 14  [17812, 18700, 19204, 19729, 20117, 20379, 207...          []

# %%
spike_waveforms = assay.extract_spike_waveforms(window_size=30)

# print(f'Spike waveforms array: {spike_waveforms}')

plot_spike_waveforms_subplots(spike_waveforms, fs=assay.fs, num_spikes=10)

# %%
assay.spike_threshold = 9
assay.plot_stim_traces(1, time_range=3, start_at=24)
# Out:
# Start time: 24
# End Time: 27
# (24, 27)

# %%
tsne_results = tsne_spike_visualization(spike_waveforms)

# %%
plot_cluster_examples(spike_waveforms, tsne_results, n_examples=3)

# %%
assay.peak_counts_df
# Out:
#             Time Range                                        Channel 804  \
# 0          0 to 100000                                                 []
# 1     100000 to 200000                                                 []
# 2     200000 to 300000                                                 []
# 3     300000 to 400000                                                 []
# 4     400000 to 500000                                                 []
# 5     500000 to 600000                                                 []
# 6     600000 to 700000  [7662, 7763, 7865, 7966, 8068, 8169, 8271, 837...
# 7     700000 to 800000  [27, 128, 230, 331, 433, 534, 636, 737, 839, 9...
# 8     800000 to 900000  [4, 106, 207, 309, 410, 512, 613, 714, 816, 91...
# 9    900000 to 1000000  [83, 185, 286, 388, 489, 591, 692, 794, 895, 9...
# 10  1000000 to 1100000                                                 []
# 11  1100000 to 1200000                                                 []
# 12  1200000 to 1300000                                                 []
# 13  1300000 to 1400000                                                 []
# 14  1400000 to 1500000                                                 []
#
#                                           Channel 656 Channel 620
# 0   [13006, 14348, 15536, 16291, 16936, 17805, 184...          []
# 1   [313, 1688, 2511, 3568, 3967, 5639, 6813, 8162...          []
# 2   [1860, 4483, 7351, 8976, 10558, 12722, 14111, ...          []
# 3   [135, 397, 943, 1222, 1592, 1882, 2106, 2373, ...          []
# 4   [38037, 39077, 39627, 40222, 40857, 41274, 415...          []
# 5   [383, 7314, 10107, 11819, 13509, 14636, 15663,...          []
# 6   [7661, 7864, 8067, 8270, 8473, 8676, 8879, 908...          []
# 7   [26, 229, 432, 635, 838, 1041, 1244, 1447, 165...          []
# 8   [2, 105, 308, 511, 714, 917, 1120, 1323, 1526,...          []
# 9   [77, 184, 387, 590, 793, 995, 1199, 1402, 1605...          []
# 10  [1501, 3116, 3973, 4555, 5708, 6674, 18000, 33...          []
# 11  [8023, 9674, 11164, 12281, 13159, 13898, 14325...          []
# 12  [2333, 6403, 8247, 10111, 12163, 13159, 14634,...          []
# 13  [13533, 14859, 15444, 16108, 16538, 17449, 178...          []
# 14  [17812, 18700, 19204, 19729, 20117, 20379, 207...          []

# %%
cluster_spike_times = get_spike_cluster_times(tsne_results, spike_waveforms)
spikes = cluster_spike_times['Vertical Chain']
compare_early_late_waveforms(spike_waveforms,spikes)
# Out:
# Number of early spikes: 274
# Number of late spikes: 260
# Early mean amplitude: 81.89 µV
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_460462/3934146338.py in <module>
#       1 cluster_spike_times = get_spike_cluster_times(tsne_results, spike_waveforms)
#       2 spikes = cluster_spike_times['Vertical Chain']
# ----> 3 compare_early_late_waveforms(spike_waveforms,spikes)
#
# /mnt/disk15tb/nathaniel/MEA_Analysis/IPNAnalysis/StimAnalysis/stim_helper_functions.py in compare_early_late_waveforms(spike_waveforms_dict, spike_times, early_threshold, late_threshold)
#     299     print(f"Number of late spikes: {len(late_spikes)}")
#     300     print(f"Early mean amplitude: {np.max(early_mean)-np.min(early_mean):.2f} µV")
# --> 301     print(f"Late mean amplitude: {np.max(late_mean)-np.min(late_mean)::.2f} µV")
#     302
#     303 def plot_evoked_waveforms(spike_waveforms_dict, stim_start, stim_length):
#
# ValueError: Invalid format specifier

# %%
assay.stim_length = 30
plot_evoked_waveforms(spike_waveforms, assay.stim_start, assay.stim_length)
# Out:
# Number of evoked spikes: 1425
# Mean evoked spike amplitude: 336.62 µV
# Mean firing rate during stim: 47.50 Hz
# (array([61.0097, 61.03  , 61.0503, ..., 90.9522, 90.9725, 90.9928]),
#  array([  -1.95508772,   -1.08982456,   -1.1122807 ,   -1.92140351,
#           -0.45052632,    0.66947368,   -1.73473684,   -0.2245614 ,
#            4.13964912,   -2.67157895,    1.75649123,   62.12982456,
#          129.57333333,   75.33754386,  -99.31649123, -207.04210526,
#         -127.71508772,   23.91017544,   82.36070175,   45.88982456,
#            9.99157895,    6.87789474,    8.03438596,    3.4477193 ,
#            2.53192982,    3.52280702,    1.98105263,    0.84070175,
#            1.13192982,    0.68280702]),
#  array([ 0.93099668,  0.94572072,  0.96392294,  0.97520027,  1.08280406,
#          1.02984315,  1.23166711,  1.21283786,  1.566135  ,  2.18388017,
#          2.26126846, 15.63403804, 16.68028749, 15.93175449, 43.6118949 ,
#         25.22059133, 22.51088354, 37.16956407, 12.94519078, 10.51727743,
#         11.15435243,  6.53029398,  1.7178761 ,  3.18244693,  2.5896958 ,
#          2.20454216,  1.83962018,  1.63574958,  2.25298199,  2.60695813]))

# %%
assay.plot_stim_traces(1, time_range=0.1, start_at=60.76)
# Out:
# Start time: 60.76
# End Time: 60.86
# (60.76, 60.86)

# %%
assay.plot_stim_traces(1, time_range=0.1, start_at=1.25)
# Out:
# Start time: 1.25
# End Time: 1.35
# (1.25, 1.35)

# %%
# Post-stim spike
assay.plot_stim_traces(1, time_range=0.1, start_at=97)
# Out:
# Start time: 97
# End Time: 97.1
# (97, 97.1)
