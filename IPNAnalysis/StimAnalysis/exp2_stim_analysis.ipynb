# %%
import sys
sys.path.append('/mnt/disk15tb/nathaniel/MEA_Analysis/IPNAnalysis/')

from StimAnalysis import StimulationAnalysis

# %% [markdown]
# # Experiment 2 - Clean Method

# %% [markdown]
# Amplitude: 50 mV\
# Distance: 7 Channels\
# Stim frequency: 1 per second

# %% [markdown]
# ## Trial 1

# %%
fp = '/mnt/disk15tb/nathaniel/Clean Stim N2/000228/data.raw.h5'
t1 = StimulationAnalysis(fp, stim_frequency=1, 
                         recording_electrode=13306, stim_electrode=14846, 
                         spike_threshold=8)
t1.pre_stim_length = 60
t1.stim_length = 60
t1_sc = t1.get_spike_counts()

# %%
t1.plot_stim_traces(1, time_range=10, start_at=10)
# Out:
# Start time: 70.0933
# End Time: 80.0933
# (70.0933, 80.0933)

# %%
t1.visible_artifact = True
t1.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 150
# Stim total spike count: 211
# Post-stim spike count: 113

# %%
avg_latency, avg_spikes_per_stim = t1.avg_inter_stim_sc()
print(f"Average spike latency: {avg_latency} seconds")
print(f"Average spikes per stim: {avg_spikes_per_stim} spikes")
# Out:
# Number of stims without spikes: 3
# evoked_peaks: 182
# Num stims 59.0
# Average spike latency: 0.36186571428571435 seconds
# Average spikes per stim: 3.0847457627118646 spikes

# %% [markdown]
# ## Trial 2

# %%
fp = '/mnt/disk15tb/nathaniel/Clean Stim N2/000226/data.raw.h5'
t2 = StimulationAnalysis(fp, stim_frequency=1, recording_electrode=13306, stim_electrode=13313, spike_threshold=8)
sc = t2.get_spike_counts()
t2.pre_stim_length = 60
t2.stim_length = 60

# %%
t2.plot_stim_traces('recording', time_range=5)
# Out:
#          Time Range                        Channel 861  \
# 0  600666 to 650665  [499, 10501, 20502, 30504, 40505]
#
#                                 Channel 913
# 0  [2338, 3729, 26064, 26084, 39727, 42054]
# Start time: 60.0666
# End Time: 65.0666
# (60.0666, 65.0666)

# %%
t2.visible_artifact = False
t2.plot_spike_counts('recording', 2)
# Out:
# Pre-stim total spike count: 293
# Stim total spike count: 205
# Post-stim spike count: 181

# %% [markdown]
# ## Trial 3

# %%
fp = '/mnt/disk15tb/nathaniel/Clean Stim N2/000230/data.raw.h5'
t3 = StimulationAnalysis(fp, stim_frequency=1, recording_electrode=13306, stim_electrode=13299, spike_threshold=9)
sc = t3.get_spike_counts()
t3.pre_stim_length = 60
t3.stim_length = 60

# %%
t3.plot_stim_traces(3, time_range=7, start_at=1)
# Out:
# <class 'pandas.core.series.Series'>
# 0    [644, 10645, 20647, 30648, 40650, 50651, 60653]
# Name: Channel 886, dtype: object
# Start time: 61.08
# End Time: 68.08
# (61.08, 68.08)

# %%
t3.visible_artifact = False
t3.plot_spike_counts('recording', 3)
# Out:
# Pre-stim total spike count: 114
# Stim total spike count: 163
# Post-stim spike count: 167

# %% [markdown]
# ## Trial 4

# %%
fp = '/mnt/disk15tb/nathaniel/Clean Stim N2/000233/data.raw.h5'
t4 = StimulationAnalysis(fp, stim_frequency=1, recording_electrode=13306, stim_electrode=11766, spike_threshold=9)
sc = t4.get_spike_counts()
t4.pre_stim_length = 60
t4.stim_length = 60

# %%
t4.plot_stim_traces(4)
# Out:
# <class 'pandas.core.series.Series'>
# 0                      []
# 1          [83919, 93921]
# 2    [3922, 13924, 23925]
# 3                      []
# 4                      []
# Name: Channel 950, dtype: object
# Start time: 41.7133
# End Time: 83.42663333333333
# (41.7133, 83.42663333333333)

# %% [markdown]
# STIM ASSAY MALFUNCTION (SEE ABOVE)
