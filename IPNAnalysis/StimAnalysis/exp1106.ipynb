# %%
import sys
sys.path.append('/mnt/disk15tb/nathaniel/MEA_Analysis/IPNAnalysis/')

from StimAnalysis import StimulationAnalysis

# %% [markdown]
# # N1

# %% [markdown]
# ## Trial 1
# Stim position: 10 channels to the right
# Stim amp: 75 mV

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/35/data.raw.h5'
t1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=20307, artifact_electrode=20306,
                         spike_threshold=8)
t1.pre_stim_length = 120
t1.stim_length = 120
t1_sc = t1.get_spike_counts()

# %%
t1.plot_stim_traces(1)

# %%
t1.visible_artifact = True
t1.plot_spike_counts('recording', 1)

# %%
t1.avg_inter_stim_sc()

# %%
t1_isi = t1.isi()
t1_isi_mean_std = t1.calc_mean_isi(t1_isi)
t1_fanofactors = t1.calculate_fano_factor(t1_isi_mean_std)
print(f"Mean and std ISI: {t1_isi_mean_std}")
print(f"Fanofactors: {t1_fanofactors}")

# %% [markdown]
# ## Trial 2
# Stim pos: 10 channels below
# Stim amp: 75 mV

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/40/data.raw.h5'
t2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=22497, artifact_electrode=22277,
                         spike_threshold=8)
t2.pre_stim_length = 120
t2.stim_length = 120
t2_sc = t2.get_spike_counts()

# %%
t2.plot_stim_traces(2, time_range=1, start_at=5)

# %%
t2.visible_artifact = False
t2.plot_spike_counts('recording', 2)

# %%
t2_isi = t2.isi()
t2_isi_mean_std = t2.calc_mean_isi(t2_isi)
t2_fanofactors = t2.calculate_fano_factor(t2_isi_mean_std)
print(f"Mean and std ISI: {t2_isi_mean_std}")
print(f"Fanofactors: {t2_fanofactors}")

# %% [markdown]
# ## Trial 3
# Stim pos: 10 channels left
# Stim amp: 75 mV

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/41/data.raw.h5'
t3 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=20287, artifact_electrode=20288,
                         spike_threshold=8)
t3.pre_stim_length = 120
t3.stim_length = 120
t3_sc = t3.get_spike_counts()

# %%
t3.plot_stim_traces(3, time_range=1, start_at=3)

# %%
t3.visible_artifact = True
t3.plot_spike_counts('recording', 3)

# %%
t3_isi_data = t3.isi()
t3_fanofactors = t3.calculate_fano_factor(t3_isi_data)
print(t3_fanofactors)

# %% [markdown]
# ## Trial 4
# Stim pos: 10 Channels above
# Stim amp: 75 mV

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/42/data.raw.h5'
t4 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=18097, artifact_electrode=18317,
                         spike_threshold=8)
t4.pre_stim_length = 120
t4.stim_length = 120
t4_sc = t4.get_spike_counts()

# %%
t4.plot_stim_traces(4)

# %% [markdown]
# # N2

# %% [markdown]
# ## Trial 1

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/43/data.raw.h5'
n2_t1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=20307, artifact_electrode=20306,
                         spike_threshold=8)
n2_t1.pre_stim_length = 120
n2_t1.stim_length = 120
n2_t1_sc = n2_t1.get_spike_counts()

# %%
n2_t1.plot_stim_traces(1, time_range=1, start_at=1)

# %%
n2_t1.visible_artifact = True
n2_t1.plot_spike_counts('recording', 1)

# %%
n2_t1_isi = n2_t1.isi()
n2_t1_isi_mean_std = n2_t1.calc_mean_isi(n2_t1_isi)
n2_t1_fanofactors = n2_t1.calculate_fano_factor(n2_t1_isi_mean_std)
print(f"Mean and std ISI: {n2_t1_isi_mean_std}")
print(f"Fanofactors: {n2_t1_fanofactors}")

# %% [markdown]
# ## Trial 2

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/44/data.raw.h5'
n2_t2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=22497, artifact_electrode=22277,
                         spike_threshold=8)
n2_t2.pre_stim_length = 120
n2_t2.stim_length = 120
n2_t2_sc = n2_t2.get_spike_counts()

# %%
n2_t2.plot_stim_traces(2, time_range=1, start_at=3)

# %%
n2_t2.visible_artifact = False
n2_t2.plot_spike_counts('recording', 2)

# %%
n2_t2_isi_data = n2_t2.isi()
n2_t2_fanofactors = n2_t2.calculate_fano_factor(n2_t2_isi_data)
print(n2_t2_fanofactors)

# %% [markdown]
# ## Trial 3

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/45/data.raw.h5'
n2_t3 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=20287, artifact_electrode=20288,
                         spike_threshold=8)
n2_t3.pre_stim_length = 120
n2_t3.stim_length = 120
n2_t3_sc = n2_t3.get_spike_counts()

# %%
n2_t3.plot_stim_traces(3, time_range=1, start_at=0)

# %%
n2_t3.visible_artifact = True
n2_t3.plot_spike_counts('recording', 3)

# %%
n2_t3_isi_data = n2_t3.isi()
n2_t3_fanofactors = n2_t3.calculate_fano_factor(n2_t3_isi_data)
print(n2_t3_fanofactors)

# %% [markdown]
# ## Trial 4

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/46/data.raw.h5'
n2_t4 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=18097, artifact_electrode=18317,
                         spike_threshold=8)
n2_t4.pre_stim_length = 120
n2_t4.stim_length = 120
n2_t4_sc = n2_t4.get_spike_counts()

# %%
n2_t4.plot_stim_traces(4, time_range=1, start_at=0)

# %% [markdown]
# # N3

# %% [markdown]
# ## Trial 1

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/47/data.raw.h5'
n3_t1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=20307, artifact_electrode=20306,
                         spike_threshold=8)
n3_t1.pre_stim_length = 120
n3_t1.stim_length = 120
n3_t1_sc = n3_t1.get_spike_counts()

# %%
n3_t1.plot_stim_traces(1, time_range=1)

# %%
n3_t1.visible_artifact = True
n3_t1.plot_spike_counts('recording', 1)

# %%
n3_t1_isi_data = n3_t1.isi()
n3_t1_fanofactors = n3_t1.calculate_fano_factor(n3_t1_isi_data)
print(n3_t1_fanofactors)

# %%
n3_t1.plot_individual_traces('recording', 1)

# %% [markdown]
# ## Trial 2

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/48/data.raw.h5'
n3_t2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=22497, artifact_electrode=22277,
                         spike_threshold=8)
n3_t2.pre_stim_length = 120
n3_t2.stim_length = 120
n3_t2_sc = n3_t2.get_spike_counts()

# %%
n3_t2.plot_stim_traces(2, time_range=0.4, start_at=0.8)

# %%
n3_t2.visible_artifact = False
n3_t2.plot_spike_counts('recording', 2)

# %%
n3_t2_isi = n3_t2.isi()
print(len(n3_t2_isi[0]))
n3_t2_isi_mean_std = n3_t2.calc_mean_isi(n3_t2_isi)
n3_t2_fanofactors = n3_t2.calculate_fano_factor(n3_t2_isi_mean_std)
print(f"Mean and std ISI: {n3_t2_isi_mean_std}")
print(f"Fanofactors: {n3_t2_fanofactors}")

# %% [markdown]
# ## Trial 3

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/49/data.raw.h5'
n3_t3 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=20287, artifact_electrode=20288,
                         spike_threshold=8)
n3_t3.pre_stim_length = 120
n3_t3.stim_length = 120
n3_t3_sc = n3_t3.get_spike_counts()

# %%
n3_t3.plot_stim_traces(3, time_range=1, start_at=0)

# %%
n3_t3.visible_artifact = True
n3_t3.plot_spike_counts('recording', 3)

# %%
n3_t3_isi_data = n3_t3.isi()
n3_t3_fanofactors = n3_t3.calculate_fano_factor(n3_t3_isi_data)
print(n3_t3_fanofactors)

# %% [markdown]
# ## Trial 4

# %%
fp = '/mnt/disk15tb/nathaniel/1106_Stims/50/data.raw.h5'
n3_t4 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20297, stim_electrode=18097, artifact_electrode=18317,
                         spike_threshold=8)
n3_t4.pre_stim_length = 120
n3_t4.stim_length = 120
n3_t4_sc = n3_t4.get_spike_counts()

# %%
n3_t4.plot_stim_traces(4, time_range=1)
