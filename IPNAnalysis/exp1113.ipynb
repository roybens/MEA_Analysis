# %%
import sys
sys.path.append('/mnt/disk15tb/nathaniel/MEA_Analysis/IPNAnalysis/')

from StimAnalysis import StimulationAnalysis

# %%
def print_isi_ff_stats(stim_assay):
    isi = stim_assay.isi()
    isi_mean_std = stim_assay.calc_mean_isi(isi)
    fanofactors = stim_assay.calculate_fano_factor(isi_mean_std)
    print(f"Mean and std ISI: {isi_mean_std}")
    print(f"Fanofactors: {fanofactors}")

# %% [markdown]
# # N1

# %% [markdown]
# ## T1

# %% [markdown]
# ### Recording Electrode 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/55/data.raw.h5'
n1_t1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=10406, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)

n1_t1.run_full_analysis()
# Out:
# Start time: 180.0
# End Time: 182.0
# Artifact detection set to visible (True).
# Start time: 180.0
# End Time: 182.0
# Pre-stim total spike count: 633
# Stim total spike count: 579
# Post-stim spike count: 529
# Mean and std ISI: {'Pre-stim ISI': (0.18821534810126583, 0.4658351970989396), 'Stim ISI': (0.22100295202952028, 0.5230135720605644), 'Post-stim ISI': (0.21195797872340427, 0.42212713227786525)}
# Fanofactors: {'Pre-stim ISI': 1.1529475839528969, 'Stim ISI': 1.2377354874563529, 'Post-stim ISI': 0.8406917110568698}

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/55/data.raw.h5'
n1_t1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=10406, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)
n1_t1.pre_stim_length = 120
n1_t1.stim_length = 120
n1_t1_sc = n1_t1.get_spike_counts()

# %%
n1_t1.visible_artifact = True
n1_t1.plot_stim_traces(1, time_range=0.1, start_at=143.2)
# interesting spike pattern from time 142 - 148
# similar spike pattern from time 28 - 33
# Out:
# Start time: 143.2
# End Time: 143.29999999999998
# (143.2, 143.29999999999998)

# %%
n1_t1.plot_stim_traces(1,time_range=0.3, start_at=0)
# Out:
# [0.000e+00 1.000e-04 2.000e-04 ... 2.997e-01 2.998e-01 2.999e-01]
# Start time: 0
# End Time: 0.3
# (0, 0.3)

# %%
n1_t1.visible_artifact = True
n1_t1.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 633
# Stim total spike count: 579
# Post-stim spike count: 529

# %%
avg_latency, avg_spikes_per_stim = n1_t1.avg_inter_stim_sc()
print(f"Average latency: {round(avg_latency, 3)} s")
print(f"Average spikes per stim: {round(avg_spikes_per_stim, 3)}")
# Out:
# Number of stims without spikes: 0
# evoked_peaks: 542
# Num stims 479.0
# Average latency: 0.113 s
# Average spikes per stim: 1.132

# %%
n1_t1_isi = n1_t1.isi()
n1_t1_isi_mean_std = n1_t1.calc_mean_isi(n1_t1_isi)
n1_t1_fanofactors = n1_t1.calculate_fano_factor(n1_t1_isi_mean_std)
print(f"Mean and std ISI: {n1_t1_isi_mean_std}")
print(f"Fanofactors: {n1_t1_fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.18821534810126583, 0.4658351970989396), 'Stim ISI': (0.22100295202952028, 0.5230135720605644), 'Post-stim ISI': (0.21195797872340427, 0.42212713227786525)}
# Fanofactors: {'Pre-stim ISI': 1.1529475839528969, 'Stim ISI': 1.2377354874563529, 'Post-stim ISI': 0.8406917110568698}

# %% [markdown]
# ### Recording Electrode 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/55/data.raw.h5'
n1_t1_e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=8212, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)
n1_t1_e2.pre_stim_length = 120
n1_t1_e2.stim_length = 120
n1_t1_e2_sc = n1_t1_e2.get_spike_counts()

# %%
n1_t1_e2.visible_artifact = True
n1_t1_e2.plot_stim_traces(1,time_range=0.5, start_at=143.2)
# interesting pattern at 140
# Out:
# Start time: 143.2
# End Time: 143.7
# (143.2, 143.7)

# %%
n1_t1_e2.visible_artifact = True
n1_t1_e2.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 783
# Stim total spike count: 794
# Post-stim spike count: 701

# %%
n1_t1_e2_isi = n1_t1_e2.isi()
n1_t1_e2_isi_mean_std = n1_t1_e2.calc_mean_isi(n1_t1_e2_isi)
n1_t1_e2_fanofactors = n1_t1_e2.calculate_fano_factor(n1_t1_e2_isi_mean_std)
print(f"Mean and std ISI: {n1_t1_e2_isi_mean_std}")
print(f"Fanofactors: {n1_t1_e2_fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.14610166240409206, 0.5367974185409461), 'Stim ISI': (0.14994432576769026, 0.58316280442068), 'Post-stim ISI': (0.1600361559139785, 0.5507934469284371)}
# Fanofactors: {'Pre-stim ISI': 1.9722668709630853, 'Stim ISI': 2.2680341834787314, 'Post-stim ISI': 1.8956555126353838}

# %% [markdown]
# ## T2

# %% [markdown]
# ### Recording Electode 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/57/data.raw.h5'
n1t2e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=10406, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)
n1t2e1.pre_stim_length = 120
n1t2e1.stim_length = 120
n1t2e1_sc = n1t2e1.get_spike_counts()

# %%
n1t2e1.visible_artifact = True
n1t2e1.plot_stim_traces(1,time_range=10, start_at=125)
# Out:
# [125.     125.0001 125.0002 ... 134.9997 134.9998 134.9999]
# Start time: 125
# End Time: 135
# (125, 135)

# %%
n1t2e1.visible_artifact = True
n1t2e1.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 782
# Stim total spike count: 838
# Post-stim spike count: 663

# %%
isi = n1t2e1.isi()
isi_mean_std = n1t2e1.calc_mean_isi(isi)
fanofactors = n1t2e1.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.15275147247119078, 0.3679193678204806), 'Stim ISI': (0.155598031496063, 0.3836122237341046), 'Post-stim ISI': (0.16198059701492534, 0.3650233049055945)}
# Fanofactors: {'Pre-stim ISI': 0.8861758189791077, 'Stim ISI': 0.9457596396516634, 'Post-stim ISI': 0.8225800841561616}

# %% [markdown]
# ### Rec Electrode 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/57/data.raw.h5'
n1t2e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=8212, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)
n1t2e2.pre_stim_length = 120
n1t2e2.stim_length = 120
n1t2e2_sc = n1t2e2.get_spike_counts()

# %%
n1t2e2.visible_artifact = True
n1t2e2.plot_stim_traces(1, time_range=10, start_at=160)
# Out:
# [160.     160.0001 160.0002 ... 169.9997 169.9998 169.9999]
# Start time: 160
# End Time: 170
# (160, 170)

# %%
n1t2e2.visible_artifact = True
n1t2e2.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 870
# Stim total spike count: 900
# Post-stim spike count: 682

# %%
isi = n1t2e2.isi()
isi_mean_std = n1t2e2.calc_mean_isi(isi)
fanofactors = n1t2e2.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.13742128883774452, 0.47437438815103294), 'Stim ISI': (0.1504691435768262, 0.5701004573790488), 'Post-stim ISI': (0.1478384223918575, 0.48323133208111646)}
# Fanofactors: {'Pre-stim ISI': 1.6375269220430946, 'Stim ISI': 2.1600078512964713, 'Post-stim ISI': 1.5795117164193404}

# %% [markdown]
# ## T3

# %% [markdown]
# ### Rec Electrode 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/58/data.raw.h5'
n1t3e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=10406, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)
n1t3e1.pre_stim_length = 120
n1t3e1.stim_length = 120
n1t3e1_sc = n1t3e1.get_spike_counts()

# %%
n1t3e1.visible_artifact = True
n1t3e1.plot_stim_traces(1, time_range=10, start_at=170)
# Out:
# [170.     170.0001 170.0002 ... 179.9997 179.9998 179.9999]
# Start time: 170
# End Time: 180
# (170, 180)

# %%
n1t3e1.visible_artifact = True
n1t3e1.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 513
# Stim total spike count: 541
# Post-stim spike count: 530

# %%
isi = n1t3e1.isi()
isi_mean_std = n1t3e1.calc_mean_isi(isi)
fanofactors = n1t3e1.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.2289322265625, 0.6257998389846129), 'Stim ISI': (0.2318714007782101, 0.68208072669072), 'Post-stim ISI': (0.20828828828828827, 0.6701461182255298)}
# Fanofactors: {'Pre-stim ISI': 1.7106610299194862, 'Stim ISI': 2.00643165203434, 'Post-stim ISI': 2.15612612434147}

# %% [markdown]
# ### Rec Electrode 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/58/data.raw.h5'
n1t3e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=8212, stim_electrode=9530, artifact_electrode=9531,
                         spike_threshold=6)
n1t3e2.pre_stim_length = 120
n1t3e2.stim_length = 120
n1t3e2_sc = n1t3e2.get_spike_counts()

# %%
n1t3e2.visible_artifact = True
n1t3e2.plot_stim_traces(3, time_range=10, start_at=140)
# Out:
# [140.     140.0001 140.0002 ... 149.9997 149.9998 149.9999]
# Start time: 140
# End Time: 150
# (140, 150)

# %%
n1t3e2.plot_spike_counts('recording', 3)
# Out:
# Pre-stim total spike count: 820
# Stim total spike count: 875
# Post-stim spike count: 868

# %%
isi = n1t3e2.isi()
isi_mean_std = n1t3e2.calc_mean_isi(isi)
fanofactors = n1t3e2.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.14092234432234432, 0.44213667769094156), 'Stim ISI': (0.1435854897218863, 0.5214397894847419), 'Post-stim ISI': (0.12973140043763676, 0.4273644711382258)}
# Fanofactors: {'Pre-stim ISI': 1.3871813068368597, 'Stim ISI': 1.893641583035581, 'Post-stim ISI': 1.4078348848091913}

# %% [markdown]
# # N2

# %% [markdown]
# ## T1

# %% [markdown]
# ### RE 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/60/data.raw.h5'
n2t1e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=22948, stim_electrode=22064, artifact_electrode=22063,
                         spike_threshold=6)
n2t1e1.pre_stim_length = 120
n2t1e1.stim_length = 120
n2t1e1_sc = n2t1e1.get_spike_counts()

# %%
n2t1e1.visible_artifact=True
n2t1e1.plot_stim_traces(1, time_range=10, start_at=200)
# Out:
# [200.     200.0001 200.0002 ... 209.9997 209.9998 209.9999]
# Start time: 200
# End Time: 210
# (200, 210)

# %%
n2t1e1.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 824
# Stim total spike count: 915
# Post-stim spike count: 792

# %%
isi = n2t1e1.isi()
isi_mean_std = n2t1e1.calc_mean_isi(isi)
fanofactors = n2t1e1.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.14429793438639127, 0.3710210971630632), 'Stim ISI': (0.1351678082191781, 0.3461777127486284), 'Post-stim ISI': (0.1429307599517491, 0.37217880274547255)}
# Fanofactors: {'Pre-stim ISI': 0.9539752258093694, 'Stim ISI': 0.8865943036492079, 'Post-stim ISI': 0.9691200218890202}

# %% [markdown]
# ### RE 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/60/data.raw.h5'
n2t1e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20967, stim_electrode=22064, artifact_electrode=22063,
                         spike_threshold=6)
n2t1e2.pre_stim_length = 120
n2t1e2.stim_length = 120
n2t1e2_sc = n2t1e2.get_spike_counts()

# %%
n2t1e2.visible_artifact=True
n2t1e2.plot_stim_traces(1, time_range=10, start_at=150)
# Out:
# [150.     150.0001 150.0002 ... 159.9997 159.9998 159.9999]
# Start time: 150
# End Time: 160
# (150, 160)

# %%
n2t1e2.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 432
# Stim total spike count: 533
# Post-stim spike count: 433

# %%
isi = n2t1e2.isi()
isi_mean_std = n2t1e2.calc_mean_isi(isi)
fanofactors = n2t1e2.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.2736781902552204, 0.9346914544507052), 'Stim ISI': (0.22836216216216215, 0.7607153704142662), 'Post-stim ISI': (0.260910538116592, 0.9271466583312843)}
# Fanofactors: {'Pre-stim ISI': 3.1922460251891045, 'Stim ISI': 2.534079504701757, 'Post-stim ISI': 3.2946194211241133}

# %% [markdown]
# ## T2

# %% [markdown]
# ### RE 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/61/data.raw.h5'
n2t2e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=22948, stim_electrode=22064, artifact_electrode=22063,
                         spike_threshold=6)
n2t2e1.pre_stim_length = 120
n2t2e1.stim_length = 120
n2t2e1_sc = n2t2e1.get_spike_counts()

# %%
n2t2e1.visible_artifact = True
n2t2e1.plot_stim_traces(2, time_range=10, start_at=150)
# Out:
# [150.     150.0001 150.0002 ... 159.9997 159.9998 159.9999]
# Start time: 150
# End Time: 160
# (150, 160)

# %%
n2t2e1.plot_spike_counts('recording', 2)
# Out:
# Pre-stim total spike count: 780
# Stim total spike count: 810
# Post-stim spike count: 864

# %%
isi = n2t2e1.isi()
isi_mean_std = n2t2e1.calc_mean_isi(isi)
fanofactors = n2t2e1.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.15387394094993584, 0.3747232981047376), 'Stim ISI': (0.15195267973856208, 0.3909434850202099), 'Post-stim ISI': (0.13215920617420063, 0.33100843034566213)}
# Fanofactors: {'Pre-stim ISI': 0.9125492547706832, 'Stim ISI': 1.005818447839855, 'Post-stim ISI': 0.8290499325145616}

# %% [markdown]
# ### RE 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/61/data.raw.h5'
n2t2e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20967, stim_electrode=22064, artifact_electrode=22063,
                         spike_threshold=6)
n2t2e2.pre_stim_length = 120
n2t2e2.stim_length = 120
n2t2e2_sc = n2t2e2.get_spike_counts()

# %%
n2t2e2.visible_artifact=True
n2t2e2.plot_stim_traces(2, time_range=10, start_at=120)
# Out:
# [120.     120.0001 120.0002 ... 129.9997 129.9998 129.9999]
# Start time: 120
# End Time: 130
# (120, 130)

# %%
n2t2e2.plot_spike_counts('recording', 2)
# Out:
# Pre-stim total spike count: 522
# Stim total spike count: 490
# Post-stim spike count: 528

# %%
isi = n2t2e2.isi()
isi_mean_std = n2t2e2.calc_mean_isi(isi)
fanofactors = n2t2e2.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.22919980806142032, 0.6628688257372798), 'Stim ISI': (0.256784531590414, 0.7342008725573651), 'Post-stim ISI': (0.21036535008976662, 0.5889523907159933)}
# Fanofactors: {'Pre-stim ISI': 1.9170831068783982, 'Stim ISI': 2.099234396734665, 'Post-stim ISI': 1.6488690669925945}

# %% [markdown]
# ## T3

# %% [markdown]
# ### RE 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/62/data.raw.h5'
n2t3e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=22948, stim_electrode=22064, artifact_electrode=22063,
                         spike_threshold=6)
n2t3e1.pre_stim_length = 120
n2t3e1.stim_length = 120
n2t3e1_sc = n2t3e1.get_spike_counts()

# %%
n2t3e1.visible_artifact=True
n2t3e1.plot_stim_traces(3, time_range=10, start_at=130)
# Out:
# [130.     130.0001 130.0002 ... 139.9997 139.9998 139.9999]
# Start time: 130
# End Time: 140
# (130, 140)

# %%
n2t3e1.plot_spike_counts('recording', 3)
# Out:
# Pre-stim total spike count: 787
# Stim total spike count: 778
# Post-stim spike count: 767

# %%
isi = n2t3e1.isi()
isi_mean_std = n2t3e1.calc_mean_isi(isi)
fanofactors = n2t3e1.calculate_fano_factor(isi_mean_std)
print(f"Mean and std ISI: {isi_mean_std}")
print(f"Fanofactors: {fanofactors}")
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.14929325699745546, 0.642755464854903), 'Stim ISI': (0.15989765193370167, 0.5970294312942228), 'Post-stim ISI': (0.1418020757020757, 0.5332381925744925)}
# Fanofactors: {'Pre-stim ISI': 2.767268903563969, 'Stim ISI': 2.2292018520653167, 'Post-stim ISI': 2.0052102101630185}

# %% [markdown]
# ### RE 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/62/data.raw.h5'
n2t3e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=20967, stim_electrode=22064, artifact_electrode=22063,
                         spike_threshold=6)
n2t3e2.pre_stim_length = 120
n2t3e2.stim_length = 120
n2t3e2_sc = n2t3e2.get_spike_counts()

# %%
n2t3e2.visible_artifact=True
n2t3e2.plot_stim_traces(3, time_range=10, start_at=120)
# Out:
# [120.     120.0001 120.0002 ... 129.9997 129.9998 129.9999]
# Start time: 120
# End Time: 130
# (120, 130)

# %%
n2t3e2.plot_spike_counts('recording', 3)
# Out:
# Pre-stim total spike count: 546
# Stim total spike count: 614
# Post-stim spike count: 522

# %%
print_isi_ff_stats(n2t3e2)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.2186651376146789, 0.7757510059688472), 'Stim ISI': (0.20362465277777778, 0.6487801190422398), 'Post-stim ISI': (0.21363279569892474, 0.6453903576759363)}
# Fanofactors: {'Pre-stim ISI': 2.7521059361649267, 'Stim ISI': 2.06711533757075, 'Post-stim ISI': 1.9497414356178344}

# %% [markdown]
# # N3

# %% [markdown]
# ## T1

# %% [markdown]
# ### RE 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/66/data.raw.h5'
n3t1e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=14808, stim_electrode=15911, artifact_electrode=15912,
                         spike_threshold=6)
n3t1e1.pre_stim_length = 120
n3t1e1.stim_length = 120
n3t1e1_sc = n3t1e1.get_spike_counts()

# %%
n3t1e1.visible_artifact=True
n3t1e1.plot_stim_traces(1, time_range=10, start_at=10)
# Out:
# Start time: 10
# End Time: 20
# (10, 20)

# %%
n3t1e1.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 569
# Stim total spike count: 485
# Post-stim spike count: 482

# %%
print_isi_ff_stats(n3t1e1)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.2034012323943662, 0.9491447561249375), 'Stim ISI': (0.250779295154185, 1.0373554174989792), 'Post-stim ISI': (0.22308943248532292, 0.9402146697073738)}
# Fanofactors: {'Pre-stim ISI': 4.429057569979697, 'Stim ISI': 4.291049073859411, 'Post-stim ISI': 3.962552664573678}

# %% [markdown]
# ### RE 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/66/data.raw.h5'
n3t1e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=17008, stim_electrode=15911, artifact_electrode=15912,
                         spike_threshold=6)
n3t1e2.pre_stim_length = 120
n3t1e2.stim_length = 120
n3t1e2_sc = n3t1e2.get_spike_counts()

# %%
n3t1e2.visible_artifact=True
n3t1e2.plot_stim_traces(1, time_range=10, start_at=150)
# Out:
# Start time: 150
# End Time: 160
# (150, 160)

# %%
n3t1e2.plot_spike_counts('recording', 1)
# Out:
# Pre-stim total spike count: 260
# Stim total spike count: 207
# Post-stim spike count: 249

# %%
print_isi_ff_stats(n3t1e2)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.44596447876447876, 1.2531999778993645), 'Stim ISI': (0.5996958549222798, 1.442439879615113), 'Post-stim ISI': (0.4369992337164751, 1.1560491962444088)}
# Fanofactors: {'Pre-stim ISI': 3.5216037585728444, 'Stim ISI': 3.4694800526405345, 'Post-stim ISI': 3.0582427634288067}

# %% [markdown]
# ## T2

# %% [markdown]
# ### RE 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/67/data.raw.h5'
n3t2e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=14808, stim_electrode=15911, artifact_electrode=15912,
                         spike_threshold=6)
n3t2e1.pre_stim_length = 120
n3t2e1.stim_length = 120
n3t2e1_sc = n3t2e1.get_spike_counts()

# %%
n3t2e1.visible_artifact=True
n3t2e1.plot_stim_traces(2, time_range=10, start_at=130)
# Out:
# Start time: 130
# End Time: 140
# (130, 140)

# %%
n3t2e1.plot_spike_counts('recording', 2)
# Out:
# Pre-stim total spike count: 483
# Stim total spike count: 571
# Post-stim spike count: 436

# %%
print_isi_ff_stats(n3t2e1)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.24027842323651452, 1.0643280000118065), 'Stim ISI': (0.2144210019267823, 1.046443897050638), 'Post-stim ISI': (0.2322189300411523, 1.0601802921502907)}
# Fanofactors: {'Pre-stim ISI': 4.714506098177957, 'Stim ISI': 5.106984949396179, 'Post-stim ISI': 4.840183578766344}

# %% [markdown]
# ### RE 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/67/data.raw.h5'
n3t2e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=17008, stim_electrode=15911, artifact_electrode=15912,
                         spike_threshold=6)
n3t2e2.pre_stim_length = 120
n3t2e2.stim_length = 120
n3t2e2_sc = n3t2e2.get_spike_counts()

# %%
n3t2e2.visible_artifact=True
n3t2e2.plot_stim_traces(2, time_range = 10, start_at=130)
# Out:
# Start time: 130
# End Time: 140
# (130, 140)

# %%
n3t2e2.plot_spike_counts('recording', 2)
# Out:
# Pre-stim total spike count: 227
# Stim total spike count: 246
# Post-stim spike count: 217

# %%
print_isi_ff_stats(n3t2e2)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.5123349557522124, 1.432476104626799), 'Stim ISI': (0.49667500000000003, 1.4923248089629912), 'Post-stim ISI': (0.4762738396624473, 1.4570903585814132)}
# Fanofactors: {'Pre-stim ISI': 4.005168429926923, 'Stim ISI': 4.4838845028367205, 'Post-stim ISI': 4.457755468105573}

# %% [markdown]
# ## T3

# %% [markdown]
# ### RE 1

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/68/data.raw.h5'
n3t3e1 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=14808, stim_electrode=15911, artifact_electrode=15912,
                         spike_threshold=6)
n3t3e1.pre_stim_length = 120
n3t3e1.stim_length = 120
n3t3e1_sc = n3t3e1.get_spike_counts()

# %%
n3t3e1.visible_artifact=True
n3t3e1.plot_stim_traces(3, time_range=10, start_at=120)
# Out:
# Start time: 120
# End Time: 130
# (120, 130)

# %%
n3t3e1.plot_spike_counts('recording', 3)
# Out:
# Pre-stim total spike count: 517
# Stim total spike count: 542
# Post-stim spike count: 489

# %%
print_isi_ff_stats(n3t3e1)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.22646356589147287, 0.9899164291277581), 'Stim ISI': (0.23464844720496894, 0.9538180305793403), 'Post-stim ISI': (0.20711190476190477, 0.9456889800472557)}
# Fanofactors: {'Pre-stim ISI': 4.327117842552481, 'Stim ISI': 3.8771568544135926, 'Post-stim ISI': 4.318089044716841}

# %% [markdown]
# ### RE 2

# %%
fp = '/mnt/disk15tb/nathaniel/1113_Stims/68/data.raw.h5'
n3t3e2 = StimulationAnalysis(fp, stim_frequency=0.25, 
                         recording_electrode=17008, stim_electrode=15911, artifact_electrode=15912,
                         spike_threshold=6)
n3t3e2.pre_stim_length = 120
n3t3e2.stim_length = 120
n3t3e2_sc = n3t3e2.get_spike_counts()

# %%
n3t3e2.visible_artifact=True
n3t3e2.plot_stim_traces(3, time_range=10, start_at=120)
# Out:
# Start time: 120
# End Time: 130
# (120, 130)

# %%
n3t3e2.plot_spike_counts('recording', 3)
# Out:
# Pre-stim total spike count: 227
# Stim total spike count: 197
# Post-stim spike count: 158

# %%
print_isi_ff_stats(n3t3e2)
# Out:
# Mean and std ISI: {'Pre-stim ISI': (0.5168880530973452, 1.4193565906444878), 'Stim ISI': (0.6785514970059879, 1.4729734924444047), 'Post-stim ISI': (0.6079048387096775, 1.522174663168337)}
# Fanofactors: {'Pre-stim ISI': 3.8975037618571946, 'Stim ISI': 3.1974742064782746, 'Post-stim ISI': 3.8114776485570925}
