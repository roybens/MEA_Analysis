# %%
import mea_analysis_pipeline as msp
import helper_functions as helper

# %%
import importlib
importlib.reload(msp)
importlib.reload(helper)
# Out:
# <module 'helper_functions' from '/mnt/disk15tb/mmpatil/MEA_Analysis/IPNAnalysis/helper_functions.py'>

# %%
file_path = '/mnt/disk15tb/primaryneurondata/KCNT1_2/KCNT1_2/230825/16378/Network/000232/data.raw.h5'

# %%
   
number_of_configurations = 29# need to know it while recording

time_in_s = 299

result = msp.routine_sequential(file_path,number_of_configurations,time_in_s)

# %%
rec_numbers = [ 3 , 4 ] # need [0],locations[8][1]to know it while recording

time_in_s = 300
for rec_number in rec_numbers:
    msp.process_block(rec_number,file_path,time_in_s)

# %%
import os
import json
import matplotlib.pyplot as plt
# %matplotlib widget
# Set the directory path
directory_path = '/mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes'

# Create empty lists to store x and y coordinates
x_coords = []
y_coords = []
count = 0
# Loop through all files in the directory
for filename in os.listdir(directory_path):
    file_path = os.path.join(directory_path, filename)
    print(file_path)
    with open(file_path, 'r') as f:
        file_contents = json.load(f)  # Load the file's contents as a dictionary
        # Loop through all templates in the dictionary
        count = count + len(file_contents)
        for template in file_contents.keys():
            channel_dict = file_contents[template]
            # Loop through all channels in the dictionary
            for channel in channel_dict.keys():
                coords = channel_dict[channel]
                plt.scatter(coords[0],coords[1])
                # Extract x and y coordinates from the list
                x_coords.append(coords[0])
                y_coords.append(coords[1])

# Print the x and y coordinates
print("X coordinates:", x_coords)
print("Y coordinates:", y_coords)
print(count)
print(len(x_coords))
plt.show()
# Out:
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0008
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0004
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0021
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0020
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0024
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0011
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0012
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0014
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0001
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0027
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0018
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0016
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0015
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0000
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0009
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0023
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0010
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0026
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0028
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0007
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0013
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0017
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0006
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0019
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0025
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0022
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0005
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0003
# /mnt/disk15tb/mmpatil/MEA_Analysis/Python/Electrodes/Electrodes_rec0002
# X coordinates: [127, 128, 129, 158, 41, 41, 157, 161, 36, 130, 160, 128, 128, 158, 41, 128, 158, 128, 156, 156, 158, 160, 99, 128, 66, 156, 97, 97, 127, 97, 128, 99, 128, 128, 41, 130, 41, 160, 128, 128, 128, 36, 160, 154, 125, 153, 153, 182, 154, 93, 3, 153, 2, 2, 154, 155, 152, 153, 152, 152, 123, 153, 154, 65, 125, 122, 92, 92, 122, 92, 122, 125, 153, 153, 153, 125, 123, 174, 144, 175, 28, 89, 24, 149, 28, 85, 25, 28, 175, 88, 89, 148, 149, 179, 148, 148, 114, 116, 114, 116, 114, 119, 116, 144, 114, 114, 174, 28, 27, 149, 27, 59, 149, 149, 174, 144, 149, 144, 149, 84, 114, 119, 118, 116, 116, 145, 29, 55, 58, 149, 58, 175, 58, 175, 57, 86, 146, 84, 88, 146, 147, 146, 116, 119, 89, 145, 115, 117, 116, 87, 118, 118, 114, 114, 58, 119, 88, 145, 134, 196, 165, 165, 132, 105, 132, 196, 16, 16, 133, 44, 137, 163, 73, 137, 132, 73, 134, 137, 136, 134, 105, 105, 103, 104, 107, 103, 133, 133, 104, 103, 132, 162, 132, 132, 137, 132, 137, 132, 12, 13, 162, 166, 162, 46, 134, 17, 162, 162, 136, 197, 162, 162, 164, 132, 133, 45, 135, 43, 134, 133, 164, 132, 132, 136, 137, 133, 73, 137, 42, 73, 162, 47, 135, 74, 135, 137, 133, 73, 74, 132, 132, 134, 132, 107, 134, 105, 133, 162, 162, 43, 133, 137, 47, 73, 135, 135, 137, 166, 165, 163, 194, 162, 194, 135, 134, 42, 42, 167, 164, 197, 134, 162, 134, 164, 134, 137, 137, 43, 136, 136, 135, 134, 134, 103, 102, 133, 134, 134, 104, 107, 104, 135, 106, 106, 105, 134, 104, 137, 162, 42, 137, 136, 103, 106, 165, 150, 2, 2, 150, 154, 34, 5, 152, 125, 4, 150, 152, 152, 120, 124, 153, 125, 124, 90, 120, 92, 95, 124, 152, 150, 212, 169, 113, 113, 113, 202, 19, 142, 173, 53, 109, 138, 82, 142, 143, 51, 143, 143, 143, 82, 112, 141, 142, 143, 142, 141, 113, 138, 113, 112, 108, 109, 83, 19, 108, 109, 173, 168, 52, 50, 113, 139, 139, 21, 19, 172, 50, 171, 50, 140, 139, 168, 142, 141, 50, 83, 50, 50, 141, 141, 142, 141, 139, 141, 108, 139, 108, 142, 140, 109, 138, 112, 111, 113, 113, 110, 113, 109, 109, 109, 112, 109, 138, 111, 112, 110, 168, 50, 110, 112, 112, 173, 142, 138, 138, 141, 140, 50, 50, 198, 51, 143, 172, 139, 140, 139, 142, 110, 139, 83, 171, 110, 138, 109, 83, 110, 113, 113, 83, 109, 139, 108, 140, 139, 83, 83, 141, 110, 110, 185, 150, 155, 151, 33, 151, 151, 151, 122, 184, 122, 155, 91, 125, 93, 92, 92, 150, 151, 90, 157, 157, 156, 126, 156, 156, 158, 9, 157, 129, 126, 41, 156, 101, 156, 160, 126, 99, 100, 101, 98, 127, 100, 66, 131, 161, 156, 126, 100, 98, 161, 39, 128, 128, 55, 58, 84, 149, 89, 84, 119, 147, 26, 58, 89, 57, 27, 174, 147, 89, 148, 146, 145, 59, 146, 147, 59, 58, 58, 146, 115, 117, 145, 145, 149, 149, 114, 84, 119, 115, 115, 117, 115, 114, 84, 117, 114, 119, 54, 89, 149, 89, 58, 148, 147, 135, 163, 163, 45, 102, 136, 137, 132, 132, 134, 163, 133, 102, 102, 132, 132, 103, 102, 102, 105, 102, 106, 105, 103, 107, 104, 72, 132, 107, 104, 103, 107, 104, 211, 212, 129, 69, 69, 69, 156, 11, 127, 189, 6, 130, 161, 157, 190, 131, 131, 36, 160, 131, 189, 6, 38, 36, 70, 161, 128, 158, 131, 160, 161, 126, 131, 69, 161, 128, 128, 158, 68, 156, 130, 127, 130, 131, 130, 126, 131, 96, 99, 97, 126, 130, 128, 126, 130, 128, 126, 96, 126, 129, 126, 129, 127, 127, 128, 133, 44, 45, 45, 196, 196, 167, 196, 195, 132, 132, 135, 163, 137, 164, 77, 162, 135, 132, 196, 42, 133, 46, 133, 136, 134, 135, 162, 105, 137, 137, 44, 133, 132, 106, 132, 132, 132, 134, 77, 74, 133, 104, 134, 135, 105, 106, 104, 107, 134, 77, 132, 136, 134, 165, 137, 136, 135, 137, 42, 134, 107, 44, 134, 167, 134, 167, 167, 165, 163, 134, 45, 49, 138, 18, 141, 138, 19, 143, 142, 168, 19, 50, 18, 51, 48, 23, 143, 139, 113, 83, 81, 111, 82, 138, 140, 139, 113, 113, 81, 139, 143, 138, 109, 110, 111, 110, 110, 112, 109, 83, 141, 141, 138, 51, 139, 81, 81, 143, 112, 113, 143, 48, 113, 130, 131, 129, 160, 160, 36, 191, 158, 129, 98, 127, 9, 129, 68, 68, 128, 130, 129, 69, 158, 68, 131, 126, 126, 126, 131, 128, 98, 99, 126, 69, 97, 98, 98, 98, 99, 97, 126, 97, 97, 126, 126, 131, 10, 9, 129, 156, 156, 69, 100, 96, 131, 97, 141, 140, 22,  ...
# Y coordinates: [79, 79, 50, 78, 50, 49, 80, 81, 52, 50, 20, 50, 50, 19, 50, 48, 113, 48, 83, 113, 78, 78, 78, 80, 113, 112, 49, 48, 21, 49, 80, 79, 80, 79, 51, 50, 50, 20, 48, 48, 79, 52, 78, 58, 58, 84, 84, 29, 58, 54, 89, 84, 89, 119, 57, 114, 84, 84, 84, 84, 26, 84, 84, 114, 86, 119, 57, 57, 89, 57, 54, 58, 84, 84, 84, 86, 26, 68, 41, 98, 37, 71, 41, 66, 38, 67, 11, 96, 98, 71, 70, 100, 101, 69, 38, 101, 101, 101, 100, 100, 101, 11, 100, 11, 101, 101, 68, 33, 35, 35, 92, 91, 35, 35, 34, 60, 35, 61, 35, 3, 35, 4, 90, 95, 90, 91, 58, 56, 54, 85, 89, 119, 114, 116, 88, 85, 116, 118, 118, 24, 24, 115, 24, 84, 86, 115, 54, 25, 26, 118, 89, 89, 119, 118, 89, 84, 118, 115, 71, 38, 67, 67, 11, 36, 36, 10, 37, 11, 69, 98, 71, 68, 101, 99, 97, 101, 101, 71, 99, 101, 96, 98, 97, 66, 68, 97, 97, 98, 96, 37, 97, 71, 36, 70, 98, 97, 98, 100, 75, 46, 72, 47, 76, 46, 47, 14, 104, 76, 46, 13, 75, 75, 15, 45, 46, 105, 74, 47, 47, 46, 76, 13, 13, 47, 47, 46, 75, 105, 75, 102, 15, 14, 103, 104, 47, 106, 46, 75, 75, 47, 74, 77, 104, 15, 102, 77, 44, 72, 76, 47, 46, 47, 14, 75, 58, 56, 85, 88, 55, 56, 88, 56, 84, 55, 59, 114, 116, 54, 88, 29, 59, 115, 59, 116, 116, 54, 54, 118, 55, 86, 55, 59, 59, 89, 89, 118, 59, 59, 89, 115, 119, 57, 119, 119, 115, 114, 115, 85, 56, 114, 54, 55, 89, 119, 55, 37, 38, 38, 36, 36, 38, 97, 71, 40, 97, 66, 39, 101, 11, 98, 101, 97, 11, 71, 11, 66, 100, 40, 66, 37, 100, 50, 48, 48, 48, 18, 108, 108, 113, 53, 50, 19, 109, 108, 18, 48, 22, 18, 19, 108, 53, 110, 20, 112, 22, 110, 23, 108, 51, 52, 78, 79, 50, 23, 78, 79, 68, 67, 39, 36, 41, 66, 71, 11, 96, 96, 7, 67, 36, 7, 36, 67, 36, 9, 36, 101, 7, 101, 101, 8, 40, 37, 97, 101, 101, 37, 70, 98, 97, 10, 71, 37, 99, 36, 36, 98, 101, 98, 101, 101, 98, 101, 98, 10, 10, 99, 67, 36, 98, 10, 10, 34, 35, 31, 35, 60, 32, 35, 35, 30, 93, 60, 95, 91, 91, 95, 93, 95, 95, 0, 61, 35, 95, 95, 3, 94, 35, 35, 3, 60, 35, 60, 91, 95, 3, 3, 60, 35, 95, 61, 35, 90, 63, 34, 63, 63, 63, 35, 94, 3, 31, 61, 90, 93, 64, 64, 64, 63, 4, 89, 29, 84, 119, 89, 89, 114, 114, 29, 59, 58, 116, 56, 89, 114, 115, 119, 88, 89, 59, 116, 119, 87, 115, 116, 56, 117, 119, 88, 114, 56, 89, 58, 58, 53, 51, 51, 83, 51, 51, 82, 48, 109, 108, 51, 113, 19, 113, 18, 52, 48, 23, 112, 112, 20, 48, 109, 112, 51, 18, 21, 21, 19, 111, 83, 83, 48, 83, 52, 51, 23, 83, 83, 51, 51, 78, 48, 52, 53, 50, 83, 52, 51, 18, 49, 31, 92, 92, 93, 92, 34, 94, 64, 94, 60, 0, 94, 92, 92, 93, 93, 35, 92, 90, 61, 92, 0, 61, 3, 61, 33, 5, 95, 61, 94, 90, 61, 90, 73, 72, 47, 73, 73, 73, 15, 72, 47, 44, 43, 46, 75, 74, 42, 45, 74, 77, 76, 45, 17, 44, 47, 42, 76, 104, 42, 77, 104, 16, 104, 77, 45, 12, 104, 44, 44, 102, 72, 104, 12, 14, 46, 45, 46, 13, 13, 105, 77, 103, 14, 102, 47, 73, 45, 47, 105, 102, 44, 47, 77, 47, 45, 45, 47, 80, 48, 49, 49, 50, 50, 51, 20, 82, 48, 81, 53, 111, 108, 83, 50, 78, 53, 49, 20, 113, 48, 81, 48, 18, 48, 48, 19, 78, 108, 110, 48, 112, 112, 111, 49, 22, 50, 23, 112, 109, 48, 80, 48, 113, 49, 113, 113, 79, 112, 112, 79, 20, 48, 81, 108, 49, 53, 108, 49, 48, 79, 48, 48, 52, 48, 51, 51, 81, 80, 48, 49, 46, 47, 43, 42, 74, 13, 43, 42, 73, 14, 77, 12, 46, 14, 43, 17, 107, 44, 13, 102, 102, 107, 106, 73, 106, 47, 47, 102, 106, 17, 106, 102, 12, 13, 12, 12, 104, 102, 75, 42, 42, 74, 46, 107, 102, 102, 17, 104, 47, 17, 46, 47, 68, 66, 68, 40, 71, 68, 41, 99, 67, 39, 37, 99, 66, 71, 67, 97, 96, 96, 6, 99, 98, 11, 39, 71, 97, 98, 39, 39, 36, 39, 6, 99, 96, 37, 36, 36, 99, 97, 97, 99, 97, 97, 101, 71, 99, 96, 101, 101, 6, 99, 96, 97, 36, 89, 58, 56, 29, 119, 59, 59, 114, 57, 57, 28, 55, 58, 118, 29, 29, 117, 119, 117, 59, 118, 25, 54, 115, 119, 88, 117, 59, 117, 58, 46, 43, 45, 43, 72, 45, 44, 42, 16, 102, 77, 43, 17, 17, 106, 72, 47, 12, 43, 43, 43, 103, 43, 103, 102, 14, 44, 17, 17, 17, 15, 46, 105, 14, 12, 47, 77, 73, 102, 102, 12, 12, 102, 74, 12, 102, 60, 91, 91, 35, 30, 32, 90, 93, 2, 62, 91, 60, 94, 3, 90, 3, 93, 95, 95, 0, 60, 60, 5, 60, 60, 65, 5, 4, 95, 93, 93, 90, 90, 65, 91, 92, 91, 35, 1, 90, 95, 92, 93, 93, 9 ...
# 1034
# 1034
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
selected_electrodes = [220 * y + x for x,y in zip(x_coords,y_coords)]
print(selected_electrodes)
# Out:
# [17507, 17508, 11129, 17318, 11041, 10821, 17757, 17981, 11476, 11130, 4560, 11128, 11128, 4338, 11041, 10688, 25018, 10688, 18416, 25016, 17318, 17320, 17259, 17728, 24926, 24796, 10877, 10657, 4747, 10877, 17728, 17479, 17728, 17508, 11261, 11130, 11041, 4560, 10688, 10688, 17508, 11476, 17320, 12914, 12885, 18633, 18633, 6562, 12914, 11973, 19583, 18633, 19582, 26182, 12694, 25235, 18632, 18633, 18632, 18632, 5843, 18633, 18634, 25145, 19045, 26302, 12632, 12632, 19702, 12632, 12002, 12885, 18633, 18633, 18633, 19045, 5843, 15134, 9164, 21735, 8168, 15709, 9044, 14669, 8388, 14825, 2445, 21148, 21735, 15708, 15489, 22148, 22369, 15359, 8508, 22368, 22334, 22336, 22114, 22116, 22334, 2539, 22116, 2564, 22334, 22334, 15134, 7288, 7727, 7849, 20267, 20079, 7849, 7849, 7654, 13344, 7849, 13564, 7849, 744, 7814, 999, 19918, 21016, 19916, 20165, 12789, 12375, 11938, 18849, 19638, 26355, 25138, 25695, 19417, 18786, 25666, 26044, 26048, 5426, 5427, 25446, 5396, 18599, 19009, 25445, 11995, 5617, 5836, 26047, 19698, 19698, 26294, 26074, 19638, 18599, 26048, 25445, 15754, 8556, 14905, 14905, 2552, 8025, 8052, 2396, 8156, 2436, 15313, 21604, 15757, 15123, 22293, 21917, 21472, 22293, 22354, 15757, 21916, 22354, 21225, 21665, 21443, 14624, 15067, 21443, 21473, 21693, 21224, 8243, 21472, 15782, 8052, 15532, 21697, 21472, 21697, 22132, 16512, 10133, 16002, 10506, 16882, 10166, 10474, 3097, 23042, 16882, 10256, 3057, 16662, 16662, 3464, 10032, 10253, 23145, 16415, 10383, 10474, 10253, 16884, 2992, 2992, 10476, 10477, 10253, 16573, 23237, 16542, 22513, 3462, 3127, 22795, 22954, 10475, 23457, 10253, 16573, 16574, 10472, 16412, 17074, 23012, 3407, 22574, 17045, 9813, 16002, 16882, 10383, 10253, 10477, 3127, 16573, 12895, 12455, 18837, 19526, 12265, 12483, 19554, 12482, 18674, 12235, 13114, 25122, 25562, 12047, 19524, 6577, 13114, 25462, 13114, 25684, 25654, 12017, 12017, 26003, 12236, 19056, 12235, 13114, 13114, 19683, 19682, 26093, 13114, 13114, 19684, 25407, 26284, 12675, 26286, 26286, 25405, 25214, 25404, 18837, 12482, 25122, 12017, 12236, 19683, 26286, 12265, 8290, 8362, 8362, 8070, 8074, 8394, 21345, 15772, 8925, 21344, 14670, 8732, 22372, 2540, 21684, 22373, 21465, 2544, 15710, 2540, 14612, 22095, 8924, 14672, 8290, 22212, 11169, 10673, 10673, 10673, 4162, 23779, 23902, 25033, 11713, 11109, 4318, 24062, 23902, 4103, 10611, 4983, 4103, 4323, 23842, 11772, 24341, 4542, 24783, 4982, 24341, 5173, 23898, 11333, 11552, 17268, 17489, 11083, 5079, 17268, 17489, 15133, 14908, 8632, 7970, 9133, 14659, 15759, 2441, 21139, 21292, 1590, 14911, 7970, 1680, 8059, 14908, 8062, 2121, 7970, 22303, 1590, 22270, 22361, 1901, 8942, 8281, 21479, 22361, 22328, 8279, 15508, 21702, 21480, 2309, 15758, 8252, 21891, 8033, 8033, 21670, 22333, 21669, 22329, 22329, 21672, 22329, 21698, 2311, 2312, 21890, 14908, 7970, 21670, 2312, 2312, 7653, 7842, 6958, 7838, 13341, 7180, 7750, 7750, 6798, 20511, 13343, 21072, 20159, 20160, 21039, 20602, 21010, 21039, 83, 13591, 7810, 21038, 21009, 743, 20790, 7813, 7813, 743, 13309, 7839, 13308, 20160, 21039, 743, 743, 13341, 7810, 21010, 13605, 7850, 19955, 14011, 7513, 14011, 14011, 14011, 7822, 20864, 782, 6975, 13511, 19925, 20553, 14172, 14172, 14230, 14011, 970, 19737, 6537, 18636, 26306, 19736, 19736, 25238, 25089, 6537, 13109, 12886, 25561, 12476, 19681, 25236, 25460, 26306, 19459, 19680, 13081, 25618, 26307, 19240, 25366, 25651, 12481, 25896, 26306, 19460, 25178, 12481, 19619, 12888, 12888, 11715, 11278, 11304, 18409, 11309, 11304, 18159, 10707, 24006, 23818, 11309, 24917, 4207, 25034, 4107, 11529, 10708, 5206, 24785, 24699, 4546, 10707, 24039, 24698, 11278, 4106, 4735, 4737, 4325, 24565, 18409, 18409, 10674, 18344, 11559, 11335, 5175, 18377, 18375, 11334, 11304, 17277, 10674, 11559, 11714, 11089, 18409, 11529, 11278, 4108, 10927, 6955, 20403, 20403, 20505, 20342, 7616, 20817, 14212, 20812, 13334, 163, 20813, 20342, 20342, 20592, 20592, 7803, 20342, 19902, 13525, 20342, 106, 13525, 763, 13527, 7364, 1172, 21032, 13527, 2078 ...

# %%
selected_electrodes = list(set(selected_electrodes))
print(selected_electrodes)
print(len(selected_electrodes))
# Out:
# [4096, 4103, 22536, 24583, 4106, 4107, 4108, 10253, 10250, 4111, 10256, 20498, 4114, 22549, 22551, 20505, 10265, 16411, 16412, 22555, 22558, 16415, 20511, 22559, 16418, 22570, 22574, 8238, 8243, 16437, 12342, 10297, 8252, 22588, 22590, 4162, 22598, 2121, 20553, 8267, 20561, 83, 12375, 8279, 8281, 14428, 14431, 8290, 106, 4207, 20592, 20591, 20602, 24699, 24698, 16512, 10378, 24717, 20621, 10383, 6301, 16542, 157, 163, 18599, 12455, 8362, 16564, 12476, 16573, 16574, 12481, 12482, 12483, 8388, 24773, 24772, 24774, 18632, 18633, 18634, 8394, 18636, 16583, 24783, 24785, 10453, 10454, 22745, 24795, 24796, 4318, 10465, 4323, 10467, 4325, 10469, 22757, 10472, 10468, 10474, 10475, 10476, 10477, 10478, 4338, 18674, 4342, 10487, 22781, 2309, 2311, 2312, 10506, 22795, 14612, 16661, 16662, 22808, 22813, 14624, 16682, 20784, 20790, 14649, 14651, 8508, 318, 14659, 24902, 20812, 14669, 14670, 20813, 14672, 20817, 24917, 12632, 2396, 24925, 24926, 18786, 20840, 8556, 10604, 10611, 6519, 6520, 20864, 12675, 2436, 24964, 24966, 2441, 6537, 12682, 2445, 18837, 12694, 16790, 10655, 10657, 6562, 18849, 24995, 22954, 6577, 10673, 10674, 25015, 25016, 8632, 25018, 4536, 4542, 10688, 4546, 10692, 10693, 10694, 10695, 4552, 25033, 25034, 16841, 4560, 22992, 10707, 10708, 14808, 476, 23011, 23012, 8678, 14825, 2539, 2540, 2544, 16880, 16882, 16884, 12789, 4596, 2551, 2552, 23036, 25089, 23042, 23041, 2564, 8706, 8708, 20996, 20999, 21009, 21010, 14869, 21016, 8732, 25122, 21030, 21032, 21038, 21039, 25138, 25145, 14905, 14908, 14911, 19009, 10821, 10822, 10825, 21072, 16976, 12885, 12886, 12888, 25178, 16990, 12895, 2658, 12899, 12900, 19045, 12898, 6757, 23145, 19056, 12914, 10877, 25214, 4735, 4737, 10885, 4745, 4747, 6798, 17039, 23184, 25235, 21139, 17045, 25238, 25236, 2709, 14996, 666, 10902, 21148, 23196, 17054, 10912, 17057, 10916, 25253, 17065, 17066, 10927, 17074, 23225, 23226, 2750, 23237, 2759, 17095, 2760, 17098, 2765, 2770, 15067, 8924, 8925, 21216, 2785, 21218, 22535, 743, 744, 21225, 21224, 8942, 15089, 15090, 763, 8960, 21249, 21250, 782, 15123, 25366, 13081, 15133, 15134, 11041, 13089, 19240, 6955, 21292, 6958, 13109, 13114, 25404, 25405, 13118, 25407, 6975, 2879, 13120, 25408, 11077, 11083, 23376, 11089, 849, 11090, 9044, 21344, 21345, 17251, 25445, 25446, 11109, 17259, 4972, 17265, 11122, 17268, 25460, 25462, 4983, 11128, 11129, 11130, 4982, 11132, 17277, 2943, 17280, 17281, 2971, 23457, 11169, 23458, 23459, 17318, 17320, 2984, 2986, 17322, 9133, 11181, 2991, 2992, 950, 11196, 21437, 21443, 970, 9164, 15313, 5079, 19417, 25562, 21465, 25561, 21468, 21466, 21471, 21472, 21473, 999, 21479, 21480, 3057, 9211, 13308, 11261, 13309, 15359, 7167, 19459, 19460, 7180, 11278, 11280, 25618, 13330, 13334, 3097, 3099, 13341, 13343, 13344, 11304, 19500, 11309, 9264, 25651, 5173, 25654, 3127, 5175, 3128, 9276, 25666, 19524, 11333, 19526, 17479, 11335, 11334, 5194, 23622, 17487, 17489, 11345, 25684, 5206, 25695, 19554, 17507, 17508, 21604, 17512, 7288, 11387, 21628, 19582, 19583, 23679, 15489, 3206, 3207, 1169, 1171, 15508, 1172, 9364, 9368, 3225, 3228, 21665, 19619, 21669, 21670, 9381, 21672, 9382, 15532, 21684, 19638, 21691, 21693, 21697, 21698, 7364, 21702, 13511, 11475, 11476, 13525, 9430, 13527, 23765, 19680, 19681, 19682, 19683, 19684, 23779, 21735, 13548, 19698, 19702, 9465, 9466, 25850, 13564, 9478, 11529, 23818, 9483, 19721, 23820, 15630, 11530, 10433, 5396, 13591, 19736, 19737, 25879, 21789, 11552, 23842, 13605, 11559, 25896, 17704, 5426, 5427, 17725, 17728, 17733, 15688, 3407, 11607, 7513, 23898, 23897, 15708, 17757, 15709, 23902, 15710, 17763, 1389, 21877, 3445, 21880, 3456, 21890, 21891, 9603, 15746, 3462, 9607, 3464, 9606, 15754, 9610, 15757, 15758, 15759, 13710, 26003, 21916, 21917, 15772, 15780, 15782, 21938, 19897, 26042, 26044, 19901, 19902, 26047, 26048, 11713, 11714, 11715, 7616, 19903, 24006, 19904, 17866, 19916, 19918, 19925, 9686, 26074, 3554, 7653, 7654, 24039, 11750, 5609, 15851, 26093, 5617, 19955, 26100, 19956, 24054, 199 ...
# 759

# %%
import pickle

with open("electrodes_13june.pkl", "wb") as f:
    pickle.dump(selected_electrodes, f)

# %%
rec_numbers = [ 0] # need [0],locations[8][1]to know it while recording

time_in_s = 300
for rec_number in rec_numbers:
    msp.process_block(rec_number,file_path,time_in_s)

# %%
sorting1min = msp.get_kilosort_result('/home/mmpatil/Documents/spikesorting/MEA_Analysis/Python/sorter_workspace/block_rec0000/kilosort3_rec0000/sorter_output')
waveforms1min = msp.get_waveforms_result('/home/mmpatil/Documents/spikesorting/MEA_Analysis/Python/sorter_workspace/block_rec0000/waveforms_rec0000',sorter=sorting1min)
waveforms_good = msp.get_waveforms_result('/home/mmpatil/Documents/spikesorting/MEA_Analysis/Python/sorter_workspace/block_rec0000/waveforms_good_rec0000',sorter=sorting1min)

# %%
sorting10min = msp.get_kilosort_result('/mnt/disk15tb/mmpatil/Spikesorting/sorter_output/sorter_5min_16757/block_rec0010/kilosort3_rec0010/sorter_output')
#waveforms10min = msp.get_waveforms_result(sorting10min,'/mnt/disk15tb/mmpatil/Spikesorting/sorter_output/sorter_5min_16757/block_rec0010/waveforms_rec0010')
waveforms10_good = msp.get_waveforms_result('/mnt/disk15tb/mmpatil/Spikesorting/sorter_output/sorter_5min_16757/block_rec0010/waveforms_good_rec0010',with_recording =False,sorter= sorting10min)

# %%
msp.analyse_waveforms_sigui(waveforms_good) #Need to implement compute noise levels.

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
metrics = msp.get_quality_metrics(waveforms_good)
metrics

# %%
non_violated_units = msp.remove_violated_units(sorting1min,waveforms1min)
print(non_violated_units)
template_channel_dict = msp.get_unique_templates_channels(non_violated_units,waveforms1min)
non_redundant_templates = list(template_channel_dict.keys())
print(non_redundant_templates)

# %%
import os
os.chdir('/home/mmpatil/Documents/spikesorting/MEA_Analysis/Python/sorter_workspace/block_rec0005')
waveform_good = waveforms1min.select_units(non_redundant_templates,new_folder='waveforms_good_rec0005')
waveform_good.run_extract_waveforms()

# %%
print(waveforms_good.unit_ids)

# %%
import axon_velocity as av

# %%
template1 = waveforms_good.get_template(unit_id =63)
template1 = template1.transpose()
print(template1.shape)
locations = waveforms_good.get_channel_locations()
gtr = av.compute_graph_propagation_velocity(template=template1, locations=locations, fs=20000)

# %%
gtr.plot_branches()

# %%
waveforms_good.run_extract_waveforms()

# %%
# %matplotlib widget
import spikeinterface.widgets as sw
import spikeinterface.postprocessing as sp
import matplotlib.pyplot as plt
locations = sp.compute_unit_locations(waveforms_good)
# print(locations.shape)
# #ax = plt.subplot(111)
# sw.plot_unit_waveforms(waveforms_good, unit_ids=[8])
# print(locations)

# %%
good_units = msp.remove_violated_units(metrics)
print(good_units)

# %%
recording,rec_name = msp.get_data_maxwell(file_path,6)
channel_location_dict = msp.get_channel_locations_mapping(recording)
print(channel_location_dict)

# %%
import spikeinterface.full
unit_extremum_channel =spikeinterface.full.get_template_extremum_channel(waveforms1min, peak_sign='neg')
    #Step 1: keep only units that are in good_units 
unit_extremum_channel = {key:value for key,value in unit_extremum_channel.items() if key in good_units}

# %%
# New dictionary with combined information
new_dict = {}
for template, channel in unit_extremum_channel.items():
    if template not in new_dict:
        new_dict[template] = {}

# Add an entry for this template and its corresponding location to the new dictionary
    new_dict[template][channel] = [int(channel_location_dict[channel][0]/17.5),int(channel_location_dict[channel][1]/17.5)]
print(new_dict)

# %%
templates = helper.get_templates_with_same_channels('/home/mmpatil/Documents/spikesorting/MEA_Analysis/Python/Electrodes_rec0010')
print(templates)

# %%
metrics = msp.get_quality_metrics(waveforms_good)

# %%
metrics

# %%
# %matplotlib widget

# %%
import spikeinterface.postprocessing as sp

locations = sp.compute_unit_locations(waveforms1min)
print(locations)
import numpy as np
#np.savetxt("unitloc_10mins.txt",locations)
ax = plt.subplot(111)
sw.plot_probe_map(recording,ax=ax,with_channel_ids=False)
for x,y in locations:
    ax.scatter(x,y)

# %%
channel_locations = recording_chunk.get_channel_locations()
channel_ids = recording_chunk.get_channel_ids()
channel_locations_mappings= {channel_id: location for location, channel_id in zip(channel_locations, channel_ids)}
print(channel_locations_mappings)

# %%
#thinking the unique locations have all the required electrodes.

required_electrodes= {channels :[int(locations[0]/17.5),int(locations[1]/17.5)] for channels, locations in channel_locations_mappings.items() if channels in unique_channels }
print(required_electrodes)

# %%
import json

with open('electrode_locations_4min.json','w') as fileptr:
    json.dump(required_electrodes,fileptr)

# %%
with open('electrode_locations_4min.json',) as fileptr:
    data = json.load(fileptr)
print(data)

# %%
selected_electrodes = [220 * locations[1] + locations[0] for locations in data.values()]
print(selected_electrodes)

# %%
val = recording_chunk.get_electrode_info
print(val)

# %%
def electrode_rectangle_indices(xmin, ymin, xmax, ymax):
    return [220 * y + x for y in range(max(ymin, 0), min(ymax + 1, 120)) for x in range(max(xmin, 0), min(xmax + 1, 220))]


def electrode_rectangle_um(xmin, ymin, xmax, ymax):
    return electrode_rectangle_indices(int(xmin / 17.5), int(ymin / 17.5), int(xmax / 17.5), int(ymax / 17.5))

XMULTIPLIER = 44
YMULTIPLIER = 20

for y in range(6):
    for x in range(5):
        #print("(",XMULTIPLIER*x,YMULTIPLIER*y,XMULTIPLIER*x+XMULTIPLIER-1,YMULTIPLIER*y+YMULTIPLIER-1,")")
        print(electrode_rectangle_indices(XMULTIPLIER*x,YMULTIPLIER*y,XMULTIPLIER*x+XMULTIPLIER-1,YMULTIPLIER*y+YMULTIPLIER-1))

# print(electrode_rectangle_indices(218,0,219,1))

# %%
import datetime as datetime

now = datetime.datetime.now()
strfmt = now.strftime("%Y%m%d_%H_%M_%S")
print(strfmt)

# %%
import maxlab.saving

obj = maxlab.saving.Saving()

obj.start()

# %%
fig, ax1 = plt.subplots(figsize=(15,5))
spike_times = {}
for idx, unit_id in enumerate(clean_sorting.get_unit_ids()):
    spike_train = clean_sorting.get_unit_spike_train(unit_id,start_frame=1*fs,end_frame=100*fs)
    print(spike_train)
    if len(spike_train) > 0:
        spike_times[idx] = spike_train / float(fs)
        #print(spike_times[unit_id])
       # print(unit_id*np.ones_like(spike_times[unit_id]))
        ax1.plot(spike_times[idx],idx*np.ones_like(spike_times[idx]),
                             marker='|', mew=1, markersize=3,
                             ls='',color='black')

# %%
t_start = 0 
t_end = int(600*fs)
dt = 1
#initialising the spike train.
units= clean_sorting.get_num_units()
frame_numbers = t_end
spike_array = np.zeros((units,frame_numbers), dtype= int)
for idx, unit_id in enumerate(clean_sorting.get_unit_ids()):
    spike_train = clean_sorting.get_unit_spike_train(unit_id,start_frame=t_start,end_frame=t_end)
    for spike_time in spike_train:
        spike_array[idx,spike_time] = 1

print(spike_array)

print(spike_array[0,63782])

# %%
np.savez_compressed('spike_array_compressed_blockactivity.npz',spike_array)

# %%
with np.load('spike_array_compressed_blockactivity.npz') as data:
    decompressed_data = data['arr_0']

print(np.array_equal(spike_array, decompressed_data))

# %%
extremum_channels_ids =spikeinterface.full.get_template_extremum_channel(waveforms, peak_sign='neg')
print(extremum_channels_ids)

# %%
colors = [ 'Lime','Gold', 'Orange','Orangered']
fig, ax = plt.subplots()
wf=[]
for i, unit_id in enumerate([34, 49]):
    wf = waveforms.get_waveforms(unit_id)
    color = colors[i]
    ax.plot(wf[:, :,channel_association_dict[594]].T, color=color, lw=0.3)
print(wf.shape)

# %%
colors = [ 'Fuchsia','Olive', 'Teal']
fig, ax = plt.subplots()
wf=[]
for i, unit_id in enumerate([218]):
    wf = waveform_good.get_waveforms(unit_id)
    ax.plot(wf[:, :,channel_association_dict[902]].T, color=colors[0], lw=0.3)
    ax.plot(wf[:, :,channel_association_dict[613]].T, color=colors[1], lw=0.3)
    ax.plot(wf[:, :,channel_association_dict[663]].T, color=colors[2], lw=0.3)
print(wf.shape)

# %%
peak_shift=si.get_template_extremum_channel_peak_shift(waveform_good)

print(peak_shift)

# %%
colors = [ 'Fuchsia','Olive', 'Teal']
fig, ax = plt.subplots()
for i, unit_id in enumerate([26, 40 , 46]):
    template = waveforms.get_template(unit_id)
    color = colors[i]
    ax.plot(template[:, channel_association_dict[780]].T, color=color, lw=3)
print(template.shape)

# %%
w = sw.plot_unit_templates(waveform_good, unit_ids=[183],plot_channels=False )

# %%
w = sw.plot_unit_waveforms(waveform_good, unit_ids=[2,4,7])
w = sw.plot_unit_templates(waveform_good, unit_ids=[2,4,7])
w = sw.plot_unit_probe_map(waveform_good, unit_ids=[2,4,7])

# %%
    all_units = sortingKS3.get_unit_ids()
    print(f"Total units counts {len(all_units)}")
    print(f"Units : {all_units}")
    rp_contamination,rp_violation = qm.compute_refrac_period_violations(waveforms)
    print(f"rp_contaminaiton : {rp_contamination}")

    refrct_violated_units = [unit for unit,ratio in rp_contamination.items() if ratio >0.0]

    snr_ratio = qm.compute_snrs(waveforms)
    print(f"SNR ratio : {snr_ratio}")
    snr_violated_units = [unit for unit,ratio in snr_ratio.items() if ratio >5]

    firing_rate = qm.compute_firing_rates(waveforms)
    print(f"Firing rate : {firing_rate}")
    fr_violated_units = [unit for unit,ratio in firing_rate.items() if ratio <=0.1]

    violated_units = list(set(refrct_violated_units+fr_violated_units))
    print(f"violated units {violated_units} removed")

    
    good_units = [units for units in all_units if units not in violated_units ]
