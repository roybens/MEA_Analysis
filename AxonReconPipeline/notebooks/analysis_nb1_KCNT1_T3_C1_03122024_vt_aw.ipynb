# %%
# '''create new ipython kernel if needed'''
# !python -m ipykernel install --user --name=axonenv
'''check python interpreter path'''
import sys
print(sys.executable)
# Out:
# /home/adamm/miniconda3/envs/axonenv/bin/python

# %%
import os
print(os.getcwd())
# Out:
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks

# %%
'''import .csv files'''
color_map = {'WT': '#0000FF',   #blue
             'HET': '#FF0000',  #red
             'HOM': '#FFA500'   #orange
             }

# Define the root path
root_path = '/home/adamm/workspace/MEA_Analysis_fork/AxonReconPipeline/data_csvs/reconstructions_KCNT1_T3_C1_03122024'

'''get current working directory, change it to project root directory'''
#os.getcwd()
#os.chdir('/home/adamm/workspace/MEA_Analysis_fork/AxonReconPipeline')
#sys.path.append('/home/adamm/workspace/MEA_Analysis_fork/AxonReconPipeline')

# Last Updated 5Aug2024, sg",
# Load the uploaded files into dataframes
# TODO: T5 doesnt have any axontracking, but T6 does and will.
files_dict = {
    "DIV10": {
        "T3": { 
            #one recording missing, well 3
            "files": [
                (os.path.join(root_path, '240322_M07037_000025_AxonTracking_well000_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240322_M07037_000025_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240322_M07037_000025_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240322_M07037_000025_AxonTracking_well004_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240322_M07037_000025_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    },
    "DIV13": {
        "T3": {
            "files": [
                (os.path.join(root_path, '240325_M07037_000036_AxonTracking_well000_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240325_M07037_000036_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240325_M07037_000036_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240325_M07037_000036_AxonTracking_well003_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240325_M07037_000036_AxonTracking_well004_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240325_M07037_000036_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    },
    "DIV16": {
        "T3": {
            "files": [
                (os.path.join(root_path, '240328_M07037_000055_AxonTracking_well000_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240328_M07037_000055_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240328_M07037_000055_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240328_M07037_000055_AxonTracking_well003_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240328_M07037_000055_AxonTracking_well004_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240328_M07037_000055_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    },
    "DIV21": {
        "T3": {
            #TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240402_M07037_000065_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240402_M07037_000065_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240402_M07037_000065_AxonTracking_well003_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240402_M07037_000065_AxonTracking_well004_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240402_M07037_000065_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    },
    "DIV24": {
        "T3": {
            #TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240405_M07037_000077_AxonTracking_well000_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240405_M07037_000077_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240405_M07037_000077_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240405_M07037_000077_AxonTracking_well004_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240405_M07037_000077_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    },
    "DIV28": {
        "T3": {
            #TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240409_M07037_000095_AxonTracking_well000_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240409_M07037_000095_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240409_M07037_000095_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240409_M07037_000095_AxonTracking_well003_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240409_M07037_000095_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    },
    "DIV31": {
        "T3": {
            #TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240412_M07037_000107_AxonTracking_well000_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240412_M07037_000107_AxonTracking_well001_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240412_M07037_000107_AxonTracking_well002_axon_analytics_template.csv'), "WT"),
                (os.path.join(root_path, '240412_M07037_000107_AxonTracking_well003_axon_analytics_template.csv'), "HOM"),
                (os.path.join(root_path, '240412_M07037_000107_AxonTracking_well004_axon_analytics_template.csv'), "HET"),
                (os.path.join(root_path, '240412_M07037_000107_AxonTracking_well005_axon_analytics_template.csv'), "WT"),
            ]
        }
    }
}

# %%
'''Validate the files_dict, exclude data as needed'''
file_paths = []
categories = []
divs = []

for div, div_data in files_dict.items():
    for t, t_data in div_data.items():
        for file_path, category in t_data["files"]:
            file_paths.append(file_path)
            categories.append(category)
            divs.append(int(div[3:]))  # Extract the DIV number

# Verify files exist
for file in file_paths:
    try:
        assert os.path.exists(file), f"File {file} does not exist"
    except Exception as e:
        print(e)
        pass

try: assert len(categories) == len(divs) == len(categories), "Length of categories and DIVs must be equal to the number of files"
except AssertionError as e: 
    print(e)
    print(len(categories), len(divs), len(file_paths))

#Modify lists to exclude data based on position in categories
#categories = [categories[i] for i in range(len(categories)) if categories[i] != 'HOM']
#categories = [categories[i] for i in range(len(categories)) if categories[i] != 'HET']
#categories = [categories[i] for i in range(len(categories)) if categories[i] != 'WT']

# %%
from lib_plot_and_analyze import *

'''Validate the data'''
# Load data with the given categories and DIVs
data = load_data(file_paths, categories, divs)

#Count units and branches in data before any validation steps
verbose = False
unit_count, branch_count = count_units_and_branches(data, verbose=verbose)
print(f'Total units: {unit_count}, Total branches: {branch_count}')
print(f'Mean Number of branches per unit: {branch_count / unit_count}')

#validate templates
# I think doing this by DIV makes the most sense since we're comparing data at each DIV
verbose = False
valid_data = validate_template_densities(
    data, 
    std=1, #Arbitrary number. #TODO: Find a good threshold - allows for n standard deviation below the mean in channel density 
    verbose=verbose,
    method='by_DIV' #Options: 'by_well', 'by_DIV', 'by_category', 'global'
    )

#valdate branch lengths, velocities, and number of branches
valid_data = validate_branch_lengths_data(valid_data, stdevs=3, min_length=0, outlier_method='by_DIV', remove_outlier_data=False)
valid_data = validate_velocity_data(valid_data, stdevs=3, outlier_method='by_DIV', remove_outlier_data=False)
valid_data = validate_and_extract_branch_counts(valid_data)

# Print the number of units and branches after all validations
unit_count, branch_count = count_units_and_branches(valid_data, verbose=False)
print(f'Total units: {unit_count}, Total branches: {branch_count}')
print(f'Mean Number of branches per unit: {branch_count / unit_count}')
print(f'validation complete')
# Out:
# Total units: 2687, Total branches: 7180
# Mean Number of branches per unit: 2.672125046520283
# Validating templates...
# Method: by_DIV
# DIV 10, Units before: 173, Units after: 135
# DIV 13, Units before: 336, Units after: 265
# DIV 16, Units before: 388, Units after: 300
# DIV 21, Units before: 411, Units after: 320
# DIV 24, Units before: 462, Units after: 362
# DIV 28, Units before: 444, Units after: 355
# DIV 31, Units before: 473, Units after: 386
# Total units: 2123, Total branches: 5675
# Validating branch lengths...
# Before: 5675 branches, After: 5675 branches
# Validating velocity data...
# Before: 5675 branches, After: 5540 branches
# Validating and extracting branch counts...
# Before: 2123 units, After: 2123 units
# Total units: 2123, Total branches: 5540
# Mean Number of branches per unit: 2.609514837494112
# validation complete

# %%
'''Explode data'''

'''Explode Data, give each unit its own row'''
exploded_data = [pd.DataFrame(well) for well in valid_data]
exploded_data = [df.explode(['unit_ids','branch_counts']) for df in exploded_data]
exploded_data_by_unit = pd.concat(exploded_data, ignore_index=True)
print(len(exploded_data_by_unit)) #This should be the total number of branches
#print(exploded_data.head())
print('Unit Data exploded')

'''Explode Data, give each branch its own row'''
exploded_data = [pd.DataFrame(well) for well in valid_data]
exploded_data = [df.explode(['length','branch_id', 'velocity']) for df in exploded_data]
exploded_data_by_branch = pd.concat(exploded_data, ignore_index=True)
print(len(exploded_data_by_branch)) #This should be the total number of branches
#print(exploded_data.head())
print('Branch Data exploded')
# Out:
# 2123
# Unit Data exploded
# 5552
# Branch Data exploded

# %%
# Plot data with significance annotations
save_svgs = False
#save_pngs = True
cat_order=['WT', 'HET', 'HOM']
#save_dir = '/home/adam/workspace/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/plots/reconstructions_KCNT1_T3_C1_03122024'

#length
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=True, print_stats=True, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=False, print_stats=False, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=True, print_stats=True, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=False, print_stats=False, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
# Out:
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:517: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# ANOVA for DIV 31: F-statistic=4.31075479298678, p-value=0.013672487078900277
# Comparing HET vs HOM at DIV 31: p-value=0.7591
# Comparing HET vs WT at DIV 31: p-value=0.0097
# Comparing HOM vs WT at DIV 31: p-value=0.0552
# ANOVA for DIV 21: F-statistic=4.248921131267903, p-value=0.014584474046080204
# Comparing HET vs HOM at DIV 21: p-value=0.375
# Comparing HET vs WT at DIV 21: p-value=0.0997
# Comparing HOM vs WT at DIV 21: p-value=0.0276
# ANOVA for DIV 28: F-statistic=3.778215344260586, p-value=0.023197203306725537
# Comparing HET vs HOM at DIV 28: p-value=0.8836
# Comparing HET vs WT at DIV 28: p-value=0.0196
# Comparing HOM vs WT at DIV 28: p-value=0.1409
# ANOVA for DIV 10: F-statistic=0.5838101831378603, p-value=0.5583851247291611
# ANOVA for DIV 24: F-statistic=0.051085275174439074, p-value=0.950199907412221
# ANOVA for DIV 13: F-statistic=0.22945409084281426, p-value=0.7950386111826039
# ANOVA for DIV 16: F-statistic=5.5567821297216105, p-value=0.0040344547345758175
# Comparing HET vs HOM at DIV 16: p-value=0.0583
# Comparing HET vs WT at DIV 16: p-value=0.3041
# Comparing HOM vs WT at DIV 16: p-value=0.0027
# Significant difference between HET and WT at DIV 31: p-value=0.0097, stars=**
# Significant difference between HOM and WT at DIV 21: p-value=0.0276, stars=*
# Significant difference between HET and WT at DIV 28: p-value=0.0196, stars=*
# Significant difference between HOM and WT at DIV 16: p-value=0.0027, stars=**
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:522: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:516: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[df['outlier']], jitter=True, dodge=True, marker='D', palette=palette, edgecolor='red', size=6, ax=ax, legend=False)
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:517: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# ANOVA for DIV 31: F-statistic=12.156643428997668, p-value=6.105439358202236e-06
# Comparing HET vs HOM at DIV 31: p-value=0.8866
# Comparing HET vs WT at DIV 31: p-value=0.0
# Comparing HOM vs WT at DIV 31: p-value=0.0001
# ANOVA for DIV 21: F-statistic=7.2634633310471015, p-value=0.0007470837463124036
# Comparing HET vs HOM at DIV 21: p-value=0.2049
# Comparing HET vs WT at DIV 21: p-value=0.0178
# Comparing HOM vs WT at DIV 21: p-value=0.0025
# ANOVA for DIV 28: F-statistic=7.322199749458067, p-value=0.0006992447570116818
# Comparing HET vs HOM at DIV 28: p-value=0.9888
# Comparing HET vs WT at DIV 28: p-value=0.0009
# Comparing HOM vs WT at DIV 28: p-value=0.0078
# ANOVA for DIV 10: F-statistic=2.0973693247328975, p-value=0.12458173662477513
# ANOVA for DIV 24: F-statistic=3.7629510425658554, p-value=0.023526434463506423
# Comparing HET vs HOM at DIV 24: p-value=0.9263
# Comparing HET vs WT at DIV 24: p-value=0.0196
# Comparing HOM vs WT at DIV 24: p-value=0.2116
# ANOVA for DIV 13: F-statistic=0.4616653915855583, p-value=0.6304649765746003
# ANOVA for DIV 16: F-statistic=20.394267514214413, p-value=2.5389224154145815e-09
# Comparing HET vs HOM at DIV 16: p-value=0.0
# Comparing HET vs WT at DIV 16: p-value=0.0392
# Comparing HOM vs WT at DIV 16: p-value=0.0
# Significant difference between HET and WT at DIV 31: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 31: p-value=0.0001, stars=****
# Significant difference between HET and WT at DIV 21: p-value=0.0178, stars=*
# Significant difference between HOM and WT at DIV 21: p-value=0.0025, stars=**
# Significant difference between HET and WT at DIV 28: p-value=0.0009, stars=***
# Significant difference between HOM and WT at DIV 28: p-value=0.0078, stars=**
# Significant difference between HET and WT at DIV 24: p-value=0.0196, stars=*
# Significant difference between HET and HOM at DIV 16: p-value=0.0, stars=****
# Significant difference between HET and WT at DIV 16: p-value=0.0392, stars=*
# Significant difference between HOM and WT at DIV 16: p-value=0.0, stars=****
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:522: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.

# %%
#velocity
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=True, print_stats=True, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=False, print_stats=False, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=True, print_stats=True, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=False, print_stats=False, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
# Out:
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:517: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# ANOVA for DIV 31: F-statistic=3.508857500672043, p-value=0.03029830808243258
# Comparing HET vs HOM at DIV 31: p-value=0.0304
# Comparing HET vs WT at DIV 31: p-value=0.9986
# Comparing HOM vs WT at DIV 31: p-value=0.192
# ANOVA for DIV 21: F-statistic=6.254060422189884, p-value=0.0020123780282945134
# Comparing HET vs HOM at DIV 21: p-value=0.9754
# Comparing HET vs WT at DIV 21: p-value=0.0019
# Comparing HOM vs WT at DIV 21: p-value=0.1592
# ANOVA for DIV 28: F-statistic=2.717064470527378, p-value=0.06656614916959369
# ANOVA for DIV 10: F-statistic=1.0358075476642352, p-value=0.3561726633340533
# ANOVA for DIV 24: F-statistic=3.506674843830852, p-value=0.030334419149709097
# Comparing HET vs HOM at DIV 24: p-value=0.0924
# Comparing HET vs WT at DIV 24: p-value=0.6681
# Comparing HOM vs WT at DIV 24: p-value=0.0238
# ANOVA for DIV 13: F-statistic=0.7025521795850793, p-value=0.4957348392775841
# ANOVA for DIV 16: F-statistic=1.0291433030509978, p-value=0.35785602096255487
# Significant difference between HET and HOM at DIV 31: p-value=0.0304, stars=*
# Significant difference between HET and WT at DIV 21: p-value=0.0019, stars=**
# Significant difference between HOM and WT at DIV 24: p-value=0.0238, stars=*
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:522: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:516: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[df['outlier']], jitter=True, dodge=True, marker='D', palette=palette, edgecolor='red', size=6, ax=ax, legend=False)
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:517: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# ANOVA for DIV 31: F-statistic=18.756563503209065, p-value=1.04082266168866e-08
# Comparing HET vs HOM at DIV 31: p-value=0.0
# Comparing HET vs WT at DIV 31: p-value=0.3628
# Comparing HOM vs WT at DIV 31: p-value=0.0
# ANOVA for DIV 21: F-statistic=14.715633902972305, p-value=5.251758437938271e-07
# Comparing HET vs HOM at DIV 21: p-value=0.7646
# Comparing HET vs WT at DIV 21: p-value=0.0
# Comparing HOM vs WT at DIV 21: p-value=0.001
# ANOVA for DIV 28: F-statistic=17.157455777035636, p-value=4.828184683106964e-08
# Comparing HET vs HOM at DIV 28: p-value=0.7142
# Comparing HET vs WT at DIV 28: p-value=0.0
# Comparing HOM vs WT at DIV 28: p-value=0.0001
# ANOVA for DIV 10: F-statistic=3.675062280092583, p-value=0.026535764540916048
# Comparing HET vs HOM at DIV 10: p-value=0.5948
# Comparing HET vs WT at DIV 10: p-value=0.0204
# Comparing HOM vs WT at DIV 10: p-value=0.2874
# ANOVA for DIV 24: F-statistic=12.97856462546471, p-value=2.7061178153292224e-06
# Comparing HET vs HOM at DIV 24: p-value=0.0001
# Comparing HET vs WT at DIV 24: p-value=0.2651
# Comparing HOM vs WT at DIV 24: p-value=0.0
# ANOVA for DIV 13: F-statistic=9.557199231468374, p-value=8.396686687664602e-05
# Comparing HET vs HOM at DIV 13: p-value=0.0
# Comparing HET vs WT at DIV 13: p-value=0.3176
# Comparing HOM vs WT at DIV 13: p-value=0.0256
# ANOVA for DIV 16: F-statistic=0.811567923314232, p-value=0.44460927826743524
# Significant difference between HET and HOM at DIV 31: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 31: p-value=0.0, stars=****
# Significant difference between HET and WT at DIV 21: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 21: p-value=0.001, stars=***
# Significant difference between HET and WT at DIV 28: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 28: p-value=0.0001, stars=****
# Significant difference between HET and WT at DIV 10: p-value=0.0204, stars=*
# Significant difference between HET and HOM at DIV 24: p-value=0.0001, stars=****
# Significant difference between HOM and WT at DIV 24: p-value=0.0, stars=****
# Significant difference between HET and HOM at DIV 13: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 13: p-value=0.0256, stars=*
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:522: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.

# %%
#branch counts
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=True, print_stats=True, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=False, print_stats=False, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=True, print_stats=True, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=False, print_stats=False, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
# Out:
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:517: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# ANOVA for DIV 16: F-statistic=1.1984495614562696, p-value=0.30311607545954894
# ANOVA for DIV 31: F-statistic=3.4596794327014413, p-value=0.032425855831023774
# Comparing HET vs HOM at DIV 31: p-value=0.0279
# Comparing HET vs WT at DIV 31: p-value=0.9696
# Comparing HOM vs WT at DIV 31: p-value=0.2373
# ANOVA for DIV 10: F-statistic=0.11385407840300382, p-value=0.8924757036198223
# ANOVA for DIV 28: F-statistic=2.3706262132519593, p-value=0.09491223947699166
# ANOVA for DIV 13: F-statistic=1.5938700823954066, p-value=0.20510120179489766
# ANOVA for DIV 24: F-statistic=11.077256766775122, p-value=2.1469009298856502e-05
# Comparing HET vs HOM at DIV 24: p-value=0.6347
# Comparing HET vs WT at DIV 24: p-value=0.0
# Comparing HOM vs WT at DIV 24: p-value=0.016
# ANOVA for DIV 21: F-statistic=7.97140925581888, p-value=0.00041908610810516197
# Comparing HET vs HOM at DIV 21: p-value=0.6351
# Comparing HET vs WT at DIV 21: p-value=0.002
# Comparing HOM vs WT at DIV 21: p-value=0.0057
# Significant difference between HET and HOM at DIV 31: p-value=0.0279, stars=*
# Significant difference between HET and WT at DIV 24: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 24: p-value=0.016, stars=*
# Significant difference between HET and WT at DIV 21: p-value=0.002, stars=**
# Significant difference between HOM and WT at DIV 21: p-value=0.0057, stars=**
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:522: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:516: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[df['outlier']], jitter=True, dodge=True, marker='D', palette=palette, edgecolor='red', size=6, ax=ax, legend=False)
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:517: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# ANOVA for DIV 16: F-statistic=0.7111630533162909, p-value=0.49191264575212856
# ANOVA for DIV 31: F-statistic=5.626763270055256, p-value=0.0039100575437092605
# Comparing HET vs HOM at DIV 31: p-value=0.0049
# Comparing HET vs WT at DIV 31: p-value=0.9826
# Comparing HOM vs WT at DIV 31: p-value=0.0432
# ANOVA for DIV 10: F-statistic=0.011813840630862587, p-value=0.9882567633188377
# ANOVA for DIV 28: F-statistic=2.325536555669379, p-value=0.09925680211427525
# ANOVA for DIV 13: F-statistic=1.2232483336444755, p-value=0.2959541249511499
# ANOVA for DIV 24: F-statistic=12.013757087105335, p-value=8.933514812824378e-06
# Comparing HET vs HOM at DIV 24: p-value=0.84
# Comparing HET vs WT at DIV 24: p-value=0.0
# Comparing HOM vs WT at DIV 24: p-value=0.0045
# ANOVA for DIV 21: F-statistic=9.065400201097447, p-value=0.0001492031086981522
# Comparing HET vs HOM at DIV 21: p-value=0.866
# Comparing HET vs WT at DIV 21: p-value=0.0004
# Comparing HOM vs WT at DIV 21: p-value=0.0074
# Significant difference between HET and HOM at DIV 31: p-value=0.0049, stars=**
# Significant difference between HOM and WT at DIV 31: p-value=0.0432, stars=*
# Significant difference between HET and WT at DIV 24: p-value=0.0, stars=****
# Significant difference between HOM and WT at DIV 24: p-value=0.0045, stars=**
# Significant difference between HET and WT at DIV 21: p-value=0.0004, stars=***
# Significant difference between HOM and WT at DIV 21: p-value=0.0074, stars=**
# /mnt/disk15tb/adamm/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:522: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
