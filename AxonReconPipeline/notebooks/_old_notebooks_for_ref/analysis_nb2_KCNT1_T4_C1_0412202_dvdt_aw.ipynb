# %%
# '''create new ipython kernel if needed'''
# !python -m ipykernel install --user --name=axonenv
'''check python interpreter path'''
import sys
print(sys.executable)
#sys.path.append('/home/adam/MEA_Analysis/AxonReconPipeline'
# Out:
# /home/adam/miniconda3/envs/axonenv/bin/python

# %%
import os

# Define a color map for different genotypes
color_map = {
    'WT': '#0000FF',   # Blue
    'HET': '#FF0000',  # Red
    'HOM': '#FFA500'   # Orange
}

# Define the root path
root_path = '/home/adam/workspace/git_workspace/MEA_Analysis_fork/AxonReconPipeline/data_csvs/reconstructions_KCNT1_T4_C1_04122024'

# Change the current working directory to the project root directory
os.chdir('/home/adam/workspace/git_workspace/MEA_Analysis_fork/AxonReconPipeline')

# Last Updated 5Aug2024, sg
# Load the uploaded files into dataframes
# TODO: T5 doesn't have any axontracking, but T6 does and will.

files_dict = {
    "DIV4": {
        "T4": {
            "files": [
                (os.path.join(root_path, '240416_M08034_000015_AxonTracking_well000_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240416_M08034_000015_AxonTracking_well001_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240416_M08034_000015_AxonTracking_well002_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240416_M08034_000015_AxonTracking_well003_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240416_M08034_000015_AxonTracking_well004_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240416_M08034_000015_AxonTracking_well005_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    },
    "DIV7": {
        "T4": {
            # Recording may have failed here? TODO: Check
            "files": [
                (os.path.join(root_path, '240419_M08034_000031_AxonTracking_well000_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240419_M08034_000031_AxonTracking_well001_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240419_M08034_000031_AxonTracking_well002_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240419_M08034_000031_AxonTracking_well003_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240419_M08034_000031_AxonTracking_well004_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240419_M08034_000031_AxonTracking_well005_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    },
    "DIV11": {
        "T4": {
            "files": [
                (os.path.join(root_path, '240423_M08034_000043_AxonTracking_well000_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240423_M08034_000043_AxonTracking_well001_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240423_M08034_000043_AxonTracking_well002_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240423_M08034_000043_AxonTracking_well003_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240423_M08034_000043_AxonTracking_well004_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240423_M08034_000043_AxonTracking_well005_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    },
    "DIV14": {
        "T4": {
            "files": [
                (os.path.join(root_path, '240426_M08034_000055_AxonTracking_well000_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240426_M08034_000055_AxonTracking_well001_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240426_M08034_000055_AxonTracking_well002_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240426_M08034_000055_AxonTracking_well003_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240426_M08034_000055_AxonTracking_well004_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240426_M08034_000055_AxonTracking_well005_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    },
    "DIV21": {
        "T4": {
            # TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240503_M08034_000082_AxonTracking_well000_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240503_M08034_000082_AxonTracking_well001_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240503_M08034_000082_AxonTracking_well002_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240503_M08034_000082_AxonTracking_well004_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240503_M08034_000082_AxonTracking_well005_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    },
    "DIV25": {
        "T4": {
            # TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240507_M08034_000094_AxonTracking_well002_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240507_M08034_000094_AxonTracking_well003_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240507_M08034_000094_AxonTracking_well004_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240507_M08034_000094_AxonTracking_well005_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    },
    "DIV28": {
        "T4": {
            # TODO: Note why there are missing data here.
            "files": [
                (os.path.join(root_path, '240510_M08034_000106_AxonTracking_well000_axon_analytics_dvdt.csv'), "Homo"),
                (os.path.join(root_path, '240510_M08034_000106_AxonTracking_well001_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240510_M08034_000106_AxonTracking_well002_axon_analytics_dvdt.csv'), "Het"),
                (os.path.join(root_path, '240510_M08034_000106_AxonTracking_well003_axon_analytics_dvdt.csv'), "Het"),
            ]
        }
    }
}

# %%
'''Validate the files_dict, exclude data as needed'''
file_paths = []
categories = []
divs = []

for div, div_data in files_dict.items():
    for t, t_data in div_data.items():
        for file_path, category in t_data["files"]:
            file_paths.append(file_path)
            categories.append(category)
            divs.append(int(div[3:]))  # Extract the DIV number

# Verify files exist
for file in file_paths:
    try:
        assert os.path.exists(file), f"File {file} does not exist"
    except Exception as e:
        print(e)
        pass

try: assert len(categories) == len(divs) == len(categories), "Length of categories and DIVs must be equal to the number of files"
except AssertionError as e: 
    print(e)
    print(len(categories), len(divs), len(file_paths))

#Modify lists to exclude data based on position in categories
#categories = [categories[i] for i in range(len(categories)) if categories[i] != 'HOM']
#categories = [categories[i] for i in range(len(categories)) if categories[i] != 'HET']
#categories = [categories[i] for i in range(len(categories)) if categories[i] != 'WT']

# %%
from lib_plot_and_analyze import *

'''Validate the data'''
# Load data with the given categories and DIVs
data = load_data(file_paths, categories, divs)

#Count units and branches in data before any validation steps
verbose = False
unit_count, branch_count = count_units_and_branches(data, verbose=verbose)
print(f'Total units: {unit_count}, Total branches: {branch_count}')
print(f'Mean Number of branches per unit: {branch_count / unit_count}')

#validate templates
# I think doing this by DIV makes the most sense since we're comparing data at each DIV
verbose = False
valid_data = validate_template_densities(
    data, 
    std=1, #Arbitrary number. #TODO: Find a good threshold - allows for n standard deviation below the mean in channel density 
    verbose=verbose,
    method='by_DIV' #Options: 'by_well', 'by_DIV', 'by_category', 'global'
    )

#valdate branch lengths, velocities, and number of branches
valid_data = validate_branch_lengths_data(valid_data, stdevs=3, min_length=0, outlier_method='by_DIV', remove_outlier_data=False)
valid_data = validate_velocity_data(valid_data, stdevs=3, outlier_method='by_DIV', remove_outlier_data=False)
valid_data = validate_and_extract_branch_counts(valid_data)

# Print the number of units and branches after all validations
unit_count, branch_count = count_units_and_branches(valid_data, verbose=False)
print(f'Total units: {unit_count}, Total branches: {branch_count}')
print(f'Mean Number of branches per unit: {branch_count / unit_count}')
print(f'validation complete')
# Out:
# Total units: 2618, Total branches: 8431
# Mean Number of branches per unit: 3.2203972498090145
# Validating templates...
# Method: by_DIV
# DIV 4, Units before: 105, Units after: 78
# DIV 7, Units before: 201, Units after: 148
# DIV 11, Units before: 375, Units after: 281
# DIV 14, Units before: 569, Units after: 428
# DIV 21, Units before: 489, Units after: 373
# DIV 25, Units before: 429, Units after: 319
# DIV 28, Units before: 450, Units after: 356
# Total units: 1983, Total branches: 6305
# Validating branch lengths...
# Before: 6305 branches, After: 6305 branches
# Validating velocity data...
# Before: 6305 branches, After: 6208 branches
# Validating and extracting branch counts...
# Before: 1983 units, After: 1983 units
# Total units: 1983, Total branches: 6208
# Mean Number of branches per unit: 3.130610186585981
# validation complete

# %%
'''Explode data'''

'''Explode Data, give each unit its own row'''
exploded_data = [pd.DataFrame(well) for well in valid_data]
exploded_data = [df.explode(['unit_ids','branch_counts']) for df in exploded_data]
exploded_data_by_unit = pd.concat(exploded_data, ignore_index=True)
print(len(exploded_data_by_unit)) #This should be the total number of branches
#print(exploded_data.head())
print('Unit Data exploded')

'''Explode Data, give each branch its own row'''
exploded_data = [pd.DataFrame(well) for well in valid_data]
exploded_data = [df.explode(['length','branch_id', 'velocity']) for df in exploded_data]
exploded_data_by_branch = pd.concat(exploded_data, ignore_index=True)
print(len(exploded_data_by_branch)) #This should be the total number of branches
#print(exploded_data.head())
print('Branch Data exploded')
# Out:
# 1983
# Unit Data exploded
# 6213
# Branch Data exploded

# %%
# Plot data with significance annotations
save_svgs = False
cat_order=['WT', 'HET', 'HOM']

#length
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=True, print_stats=True, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=False, print_stats=False, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=True, print_stats=True, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'length', 'Branch Length Comparison by Category and DIV with Significance', 'Branch Length (µm)', scatter=False, print_stats=False, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_length_comparison.svg', format='svg')
# Out:
# 2024-08-08 01:15:28,957 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:28,957 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:28,958 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:515: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# Comparing Homo vs Het at DIV 4: t-statistic=-1.2449886115285216, p-value=0.21480051277117088
# Comparing Homo vs Het at DIV 21: t-statistic=0.3658453493845827, p-value=0.7145424799632194
# Comparing Homo vs Het at DIV 28: t-statistic=0.6297716154943547, p-value=0.5289683607462471
# Comparing Homo vs Het at DIV 7: t-statistic=-1.068487967899507, p-value=0.28610081411575056
# Comparing Homo vs Het at DIV 25: t-statistic=-1.5342667102060552, p-value=0.12529318925263666
# Comparing Homo vs Het at DIV 11: t-statistic=-0.1707404006245974, p-value=0.8644672317467395
# Comparing Homo vs Het at DIV 14: t-statistic=2.029561702567677, p-value=0.04258304752751262
# Significant difference between Homo and Het at DIV 14: p-value=0.04258304752751262, stars=*
# 2024-08-08 01:15:29,355 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:29,356 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:29,356 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:520: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# 2024-08-08 01:15:29,578 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:29,579 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:29,579 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[df['outlier']], jitter=True, dodge=True, marker='D', palette=palette, edgecolor='red', size=6, ax=ax, legend=False)
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:515: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# Comparing Homo vs Het at DIV 4: t-statistic=-0.7267534878283791, p-value=0.4684130438444042
# Comparing Homo vs Het at DIV 21: t-statistic=4.480036083838926, p-value=8.22518161218336e-06
# Comparing Homo vs Het at DIV 28: t-statistic=4.371657656465123, p-value=1.3596436804077044e-05
# Comparing Homo vs Het at DIV 7: t-statistic=-2.499906660154502, p-value=0.012951123828703195
# Comparing Homo vs Het at DIV 25: t-statistic=-3.4968958993850774, p-value=0.0004951892776632168
# Comparing Homo vs Het at DIV 11: t-statistic=0.9578020888177368, p-value=0.3384597219168749
# Comparing Homo vs Het at DIV 14: t-statistic=6.709081159587952, p-value=2.920390319055246e-11
# Significant difference between Homo and Het at DIV 21: p-value=8.22518161218336e-06, stars=****
# Significant difference between Homo and Het at DIV 28: p-value=1.3596436804077044e-05, stars=****
# Significant difference between Homo and Het at DIV 7: p-value=0.012951123828703195, stars=*
# Significant difference between Homo and Het at DIV 25: p-value=0.0004951892776632168, stars=***
# Significant difference between Homo and Het at DIV 14: p-value=2.920390319055246e-11, stars=****
# 2024-08-08 01:15:29,958 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:29,959 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:29,959 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:520: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.

# %%
#velocity
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=True, print_stats=True, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=False, print_stats=False, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=True, print_stats=True, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_branch, 'velocity', 'Velocity Comparison by Category and DIV with Significance', 'Velocity (µm/s)', scatter=False, print_stats=False, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('velocity_comparison_noscatter.svg', format='svg')
# Out:
# 2024-08-08 01:15:30,214 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:30,215 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:30,216 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:515: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# Comparing Homo vs Het at DIV 4: t-statistic=-1.4012539671600222, p-value=0.1629090498315596
# Comparing Homo vs Het at DIV 21: t-statistic=-1.3297377300381028, p-value=0.1838476837996711
# Comparing Homo vs Het at DIV 28: t-statistic=-1.0273735827479822, p-value=0.3044593185662704
# Comparing Homo vs Het at DIV 7: t-statistic=0.15517716911570564, p-value=0.8767788732033422
# Comparing Homo vs Het at DIV 25: t-statistic=0.43191431736537617, p-value=0.6659005754861824
# Comparing Homo vs Het at DIV 11: t-statistic=-0.07446041170064813, p-value=0.9406610013635579
# Comparing Homo vs Het at DIV 14: t-statistic=-1.753342989492224, p-value=0.07975400180765309
# 2024-08-08 01:15:30,696 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:30,696 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:30,697 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:520: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# 2024-08-08 01:15:30,908 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:30,909 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:30,909 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[df['outlier']], jitter=True, dodge=True, marker='D', palette=palette, edgecolor='red', size=6, ax=ax, legend=False)
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:515: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# Comparing Homo vs Het at DIV 4: t-statistic=-0.6460492176061992, p-value=0.5191186277363806
# Comparing Homo vs Het at DIV 21: t-statistic=-3.2678596181942634, p-value=0.0011142591119949656
# Comparing Homo vs Het at DIV 28: t-statistic=-0.13601441971839104, p-value=0.8918343895301342
# Comparing Homo vs Het at DIV 7: t-statistic=0.4783035477924676, p-value=0.6327659573643575
# Comparing Homo vs Het at DIV 25: t-statistic=-1.4207128695844549, p-value=0.15573907273396764
# Comparing Homo vs Het at DIV 11: t-statistic=-0.31261467653558517, p-value=0.7546490378086692
# Comparing Homo vs Het at DIV 14: t-statistic=-3.282108979102556, p-value=0.0010554263993029812
# Significant difference between Homo and Het at DIV 21: p-value=0.0011142591119949656, stars=**
# Significant difference between Homo and Het at DIV 14: p-value=0.0010554263993029812, stars=**
# 2024-08-08 01:15:31,290 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:31,291 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:31,292 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:520: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.

# %%
#branch counts
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=True, print_stats=True, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=False, print_stats=False, cat_order=cat_order)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=True, print_stats=True, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
ax = plot_with_significance(exploded_data_by_unit, 'branch_counts', 'Branch Count Comparison by Category and DIV with Significance', 'Branch Counts', scatter=False, print_stats=False, cat_order=cat_order, exclude_outliers=True)
if save_svgs: ax.get_figure().savefig('branch_count_comparison_noscatter.svg', format='svg')
# Out:
# 2024-08-08 01:15:31,523 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:31,524 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:31,524 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:515: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# Comparing Homo vs Het at DIV 21: t-statistic=-0.3385445666889878, p-value=0.7351443608757764
# Comparing Homo vs Het at DIV 4: t-statistic=-0.3360394701160421, p-value=0.7377670976269998
# Comparing Homo vs Het at DIV 7: t-statistic=-1.5992739423423663, p-value=0.11192157273876922
# Comparing Homo vs Het at DIV 28: t-statistic=-0.6453821641485072, p-value=0.5190976300774375
# Comparing Homo vs Het at DIV 25: t-statistic=-1.1417376782877957, p-value=0.25442477375334716
# Comparing Homo vs Het at DIV 11: t-statistic=-1.9399690683586597, p-value=0.05339104858920693
# Comparing Homo vs Het at DIV 14: t-statistic=1.132042665238796, p-value=0.25825330366958255
# 2024-08-08 01:15:31,846 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:31,847 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:31,847 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:520: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
# 2024-08-08 01:15:32,045 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:32,045 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:32,046 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:512: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[~df['outlier']], jitter=True, dodge=True, marker='o', alpha=0.6, palette=palette, edgecolor='gray')
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:514: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax = sns.stripplot(x='DIV', y=y, hue='category', data=sorted_data[df['outlier']], jitter=True, dodge=True, marker='D', palette=palette, edgecolor='red', size=6, ax=ax, legend=False)
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:515: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette, alpha=0.6, errorbar='se',
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# Comparing Homo vs Het at DIV 21: t-statistic=-0.9209448485015468, p-value=0.35769085169166615
# Comparing Homo vs Het at DIV 4: t-statistic=-0.3360394701160421, p-value=0.7377670976269998
# Comparing Homo vs Het at DIV 7: t-statistic=-1.3193566145642737, p-value=0.1891294600305992
# Comparing Homo vs Het at DIV 28: t-statistic=0.04749296714524556, p-value=0.9621478955291292
# Comparing Homo vs Het at DIV 25: t-statistic=-1.0512811573185616, p-value=0.29393274486503784
# Comparing Homo vs Het at DIV 11: t-statistic=-1.248039939062942, p-value=0.2130818913922424
# Comparing Homo vs Het at DIV 14: t-statistic=1.3724388765288158, p-value=0.17065584498350117
# 2024-08-08 01:15:32,309 - WARNING - Category 'WT' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:32,310 - WARNING - Category 'HET' not found in data. - lib_plot_and_analyze.plot_with_significance
# 2024-08-08 01:15:32,310 - WARNING - Category 'HOM' not found in data. - lib_plot_and_analyze.plot_with_significance
# Disclaimer: Significance levels are indicated as follows: * for p <= 0.05, ** for p <= 0.01, *** for p <= 0.001, **** for p <= 0.0001.
# /mnt/disk15tb/adam/git_workspace/MEA_Analysis_fork/AxonReconPipeline/notebooks/lib_plot_and_analyze.py:520: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1}` instead.
#
#   ax = sns.barplot(x='DIV', y=y, hue='category', data=sorted_data, palette=palette,
